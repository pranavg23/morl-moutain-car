# %% [markdown]
# ## Step 1: install and import the libraries

# %%
# from google.colab import drive
# drive.mount('/gdrive')
# %cd /gdrive/My\ Drive
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/My Drive

# %%
# !pip install gymnasium
import gymnasium as gym
import mo_gymnasium as mo
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt
# Out:
# Collecting gymnasium
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.10.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1

# %%
import sys
# !{sys.executable} -m pip install moviepy
# Out:
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.66.2)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from moviepy) (1.25.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.31.6)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.4.9)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio<3.0,>=2.5->moviepy) (9.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg>=0.2.0->moviepy) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2024.2.2)

# %% [markdown]
# ## Step 2: create an environment

# %%
#Input is changed here to reduce mistakes
environment = "velocity-move-v2" #"mo-mountaincar-velocity"
entry_pt = "mo_gymnasium.envs.velocity_move_v2.velocity_move_v2:MOMountainCar" #"mo_gymnasium.envs.mountain_car_velocity.mountain_car_velocity:MOMountainCar"

# %%
#Run twice for registration (No clue why)
gym.envs.register(
    id=environment,
    entry_point=entry_pt,
    max_episode_steps=200,
) #Register the environment before calling
env = mo.make(environment, render_mode="rgb_array")
# Out:
# Box([-1.  0.], [0.  1.1], (2,), float32)
# /usr/local/lib/python3.10/dist-packages/gymnasium/envs/registration.py:694: UserWarning: WARN: Overriding environment velocity-move-v2 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
#Run twice for registration (No clue why)
gym.envs.register(
    id=environment,
    entry_point=entry_pt,
    max_episode_steps=200,
) #Register the environment before calling
env = mo.make(environment, render_mode="rgb_array")
# Out:
# Box([-1.  0.], [0.  1.1], (2,), float32)

# %% [markdown]
# ## Step 3: extract environment information

# %%
# env.observation_space
# Out:
# Box([-1.2  -0.07], [0.6  0.07], (2,), float32)

# %%
env.action_space
# Out:
# Discrete(3)

# %%
env.unwrapped.reward_dim
# Out:
# 3

# %% [markdown]
# ## Step 4: use Gymnasium features in MO-Gymnasium

# %%
from gymnasium.wrappers.record_video import RecordVideo

# %% [markdown]
# ## Step 5: go through the environment with a random agent

# %% [markdown]
# ## Step 6: scalarize env and run it with stable-baselines3

# %%
# !pip install stable-baselines3 --upgrade
# Out:
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.2.1-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.7/181.7 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.25.2)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.2.1+cu121)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3) (3.7.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.13.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 39.6 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 45.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 45.1 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.1 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.3 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 1.2 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 451.4 kB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 997.7 kB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 1.2 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.13->stable-baselines3)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13->stable-baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.99-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3) (2023.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13->stable-baselines3) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable-baselines3
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.99 nvidia-nvtx-cu12-12.1.105 stable-baselines3-2.2.1

# %%
import stable_baselines3 as sb3
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.monitor import Monitor
import numpy as np
#import mo_gymnasium as mo_gym
import os
import time

# %%
##Evaluating it for the single case:

# env = gym.make('MountainCar-v0', render_mode="rgb_array")
# agent = sb3.DQN(policy="MlpPolicy",
#     env=env,
#     seed=0,
#     learning_rate=0.0001,
#     buffer_size=int(2e5),  # Replay buffer size
#     learning_starts=1000,  # Number of steps before starting training
#     train_freq=4,          # Number of actions between updates
#     gradient_steps=1,      # Number of optimization steps per batch
#     target_update_interval=1000,  # Frequency (in steps) to update the target network
#     exploration_fraction=1,     # Fraction of the total training steps for exploration
#     exploration_final_eps=0,   # Final epsilon value for exploration
#     gamma=0.9,
#     max_grad_norm=5,
#     policy_kwargs=None,
#     verbose=1)

# #Works very well!

# agent.learn(total_timesteps=300000,progress_bar=True)  #Number of episodes?

# #Can save each model I learn and see which one is the best
# #timesteps is 200000
# mean_reward, std_reward = evaluate_policy(agent, agent.get_env(), n_eval_episodes=10) #Originally 10
# print(f"Mean reward: {mean_reward} and Standard Deviation: {std_reward}")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Output()
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | -200     |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4973     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 800      |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-ca3c38727b87> in <cell line: 21>()
#      19 #Works very well!
#      20
# ---> 21 agent.learn(total_timesteps=300000,progress_bar=True)  #Number of episodes?
#      22
#      23 #Can save each model I learn and see which one is the best
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/dqn/dqn.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     265         progress_bar: bool = False,
#     266     ) -> SelfDQN:
# --> 267         return super().learn(
#     268             total_timesteps=total_timesteps,
#     269             callback=callback,
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345                 # Special case when the user passes `gradient_steps=0`
#     346                 if gradient_steps > 0:
# --> 347                     self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     348
#     349         callback.on_training_end()
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/dqn/dqn.py in train(self, gradient_steps, batch_size)
#     215             # Optimize the policy
#     216             self.policy.optimizer.zero_grad()
# --> 217             loss.backward()
#     218             # Clip gradient norm
#     219             th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     490                 inputs=inputs,
#     491             )
# --> 492         torch.autograd.backward(
#     493             self, gradient, retain_graph, create_graph, inputs=inputs
#     494         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     249     # some Python versions print out the first line of a multi-line function
#     250     # calls in the traceback and some print out the last line
# --> 251     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252         tensors,
#     253         grad_tensors_,
#
# KeyboardInterrupt:

# %%
###For a total reward
# class SaveOnBestTrainingRewardCallback(BaseCallback):
#     """
#     Callback for saving a model (the check is done every ``check_freq`` steps)
#     based on the training reward (in practice, we recommend using ``EvalCallback``).

#     :param check_freq: (int)
#     :param log_dir: (str) Path to the folder where the model will be saved.
#       It must contains the file created by the ``Monitor`` wrapper.
#     :param verbose: (int)
#     """
#     def __init__(self, check_freq: int, log_dir: str, verbose=1):
#         super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
#         self.check_freq = check_freq
#         self.log_dir = log_dir
#         self.save_path = os.path.join(log_dir, 'best_model')
#         self.best_mean_reward = -np.inf

#     def _init_callback(self) -> None:
#         # Create folder if needed
#         if self.save_path is not None:
#             os.makedirs(self.save_path, exist_ok=True)

#     def _on_step(self) -> bool:
#         if self.n_calls % self.check_freq == 0:

#           # Retrieve training reward
#           x, y = ts2xy(load_results(self.log_dir), 'timesteps')
#           if len(x) > 0:
#               # Mean training reward over the last 100 episodes
#               mean_reward = np.mean(y[-100:])
#               if self.verbose > 0:
#                 print("Num timesteps: {}".format(self.num_timesteps))
#                 print("Best mean reward: {:.2f} - Last mean reward per episode: {:.2f}".format(self.best_mean_reward, mean_reward))

#               # New best model, you could save the agent here
#               if mean_reward > self.best_mean_reward:
#                   self.best_mean_reward = mean_reward
#                   # Example for saving best model
#                   if self.verbose > 0:
#                     print("Saving new best model to {}".format(self.save_path))
#                   self.model.save(self.save_path)

#         return True
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
###For the reward for each objective
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contain the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq: int, log_dir: str, reward_dim: int, verbose=1):
        super(SaveOnBestTrainingRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, 'best_model')
        self.best_mean_rewards = {0: -np.inf, 1: -np.inf}  # Assuming -1 and 0 are the indices for objectives
        self.objective_indices = [0, 1]  # Objective indices
        self.reward_dim = reward_dim
        self.episode_sum = [0]*self.reward_dim

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.training_env.buf_dones[0]:
          training_values.append((self.episode_sum,self.training_env.buf_infos[0].get("TimeLimit.truncated"))) #Change the code
          self.episode_sum = [0]*self.reward_dim
        else:
          self.episode_sum += self.training_env.buf_infos[0].get("vector_reward")
        return True
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Linear scalarizes the environment
training_values=[]
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)
scalar_weight=np.array([0.07,0.93])
steps = 400000
env = mo.LinearReward(mo.make(environment, render_mode="rgb_array"), weight=scalar_weight) #Since 2nd objective is positive, will give it same weightage
env = Monitor(env, log_dir)
#env = mo.LinearReward(mo.make("mo-mountaincar-velocity", render_mode="rgb_array"), weight=np.array([0.9, 0.1]))

values = []

print("Action space:", env.action_space)
# for action_index in range(env.action_space.n):
#         print(f"Action index {action_index} corresponds to action: {env.unwrapped.get_action_meanings()[action_index]}")4

agent = sb3.DQN(policy="MlpPolicy",
    env=env,
    seed=0,
    learning_rate=0.0001, #Originally, 0.0001
    buffer_size=int(2e4),  # Replay buffer size
    learning_starts=1000,  # Number of steps before starting training
    train_freq=4,          # Number of actions between updates
    gradient_steps=1,      # Number of optimization steps per batch
    target_update_interval=1000,  # Frequency (in steps) to update the target network
    exploration_fraction=1,     # Fraction of the total training steps for exploration
    exploration_final_eps=0,   # Final epsilon value for exploration
    gamma=0.9,
    max_grad_norm=5,
    policy_kwargs=None,
    verbose=1)
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir, reward_dim=env.unwrapped.reward_dim)
agent.learn(total_timesteps=steps, callback=callback) #, callback=callback #200000
#,progress_bar=True , callback=callback

agent.save(f"DQN-{environment}-{scalar_weight}-{steps}")

#Can save each model I learn and see which one is the best
#timesteps is 200000
mean_reward, std_reward = evaluate_policy(agent, agent.get_env(), n_eval_episodes=10) #Originally 10
print(f"Mean reward: {mean_reward} and Standard Deviation: {std_reward}")
# Out:
# Streaming output truncated to the last 5000 lines.
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00131  |
# |    n_updates        | 40749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 8.97     |
# |    exploration_rate | 0.588    |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 748      |
# |    time_elapsed     | 220      |
# |    total_timesteps  | 164800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00563  |
# |    n_updates        | 40949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 9.76     |
# |    exploration_rate | 0.586    |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 748      |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 165600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000853 |
# |    n_updates        | 41149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.584    |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 749      |
# |    time_elapsed     | 222      |
# |    total_timesteps  | 166400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00556  |
# |    n_updates        | 41349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.582    |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 749      |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 167200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00246  |
# |    n_updates        | 41549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.58     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 750      |
# |    time_elapsed     | 223      |
# |    total_timesteps  | 168000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00167  |
# |    n_updates        | 41749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 12.6     |
# |    exploration_rate | 0.578    |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 750      |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 168800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00127  |
# |    n_updates        | 41949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 13.1     |
# |    exploration_rate | 0.576    |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 749      |
# |    time_elapsed     | 226      |
# |    total_timesteps  | 169600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00315  |
# |    n_updates        | 42149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 13.6     |
# |    exploration_rate | 0.574    |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 748      |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 170400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00298  |
# |    n_updates        | 42349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 14.6     |
# |    exploration_rate | 0.572    |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 749      |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 171200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00426  |
# |    n_updates        | 42549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 15.4     |
# |    exploration_rate | 0.57     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 749      |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 172000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00231  |
# |    n_updates        | 42749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 15.8     |
# |    exploration_rate | 0.568    |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 750      |
# |    time_elapsed     | 230      |
# |    total_timesteps  | 172800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00277  |
# |    n_updates        | 42949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 16.4     |
# |    exploration_rate | 0.566    |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 751      |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 173600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00408  |
# |    n_updates        | 43149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 17.1     |
# |    exploration_rate | 0.564    |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 751      |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 174400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00326  |
# |    n_updates        | 43349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.562    |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 752      |
# |    time_elapsed     | 232      |
# |    total_timesteps  | 175200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00161  |
# |    n_updates        | 43549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 18.7     |
# |    exploration_rate | 0.56     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 753      |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 176000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00287  |
# |    n_updates        | 43749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 19.5     |
# |    exploration_rate | 0.558    |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 753      |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 176800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00332  |
# |    n_updates        | 43949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.556    |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 753      |
# |    time_elapsed     | 235      |
# |    total_timesteps  | 177600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00206  |
# |    n_updates        | 44149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.554    |
# | time/               |          |
# |    episodes         | 892      |
# |    fps              | 754      |
# |    time_elapsed     | 236      |
# |    total_timesteps  | 178400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00126  |
# |    n_updates        | 44349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 22.1     |
# |    exploration_rate | 0.552    |
# | time/               |          |
# |    episodes         | 896      |
# |    fps              | 754      |
# |    time_elapsed     | 237      |
# |    total_timesteps  | 179200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0019   |
# |    n_updates        | 44549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 23       |
# |    exploration_rate | 0.55     |
# | time/               |          |
# |    episodes         | 900      |
# |    fps              | 753      |
# |    time_elapsed     | 238      |
# |    total_timesteps  | 180000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00191  |
# |    n_updates        | 44749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 23.9     |
# |    exploration_rate | 0.548    |
# | time/               |          |
# |    episodes         | 904      |
# |    fps              | 753      |
# |    time_elapsed     | 240      |
# |    total_timesteps  | 180800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00114  |
# |    n_updates        | 44949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 25       |
# |    exploration_rate | 0.546    |
# | time/               |          |
# |    episodes         | 908      |
# |    fps              | 753      |
# |    time_elapsed     | 240      |
# |    total_timesteps  | 181600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000764 |
# |    n_updates        | 45149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 25.3     |
# |    exploration_rate | 0.544    |
# | time/               |          |
# |    episodes         | 912      |
# |    fps              | 754      |
# |    time_elapsed     | 241      |
# |    total_timesteps  | 182400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000738 |
# |    n_updates        | 45349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 25.4     |
# |    exploration_rate | 0.542    |
# | time/               |          |
# |    episodes         | 916      |
# |    fps              | 754      |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 183200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00174  |
# |    n_updates        | 45549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 25.5     |
# |    exploration_rate | 0.54     |
# | time/               |          |
# |    episodes         | 920      |
# |    fps              | 754      |
# |    time_elapsed     | 243      |
# |    total_timesteps  | 184000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00197  |
# |    n_updates        | 45749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 26.4     |
# |    exploration_rate | 0.538    |
# | time/               |          |
# |    episodes         | 924      |
# |    fps              | 755      |
# |    time_elapsed     | 244      |
# |    total_timesteps  | 184800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00103  |
# |    n_updates        | 45949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 26.4     |
# |    exploration_rate | 0.536    |
# | time/               |          |
# |    episodes         | 928      |
# |    fps              | 755      |
# |    time_elapsed     | 245      |
# |    total_timesteps  | 185600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000763 |
# |    n_updates        | 46149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 26.3     |
# |    exploration_rate | 0.534    |
# | time/               |          |
# |    episodes         | 932      |
# |    fps              | 756      |
# |    time_elapsed     | 246      |
# |    total_timesteps  | 186400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000995 |
# |    n_updates        | 46349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 26       |
# |    exploration_rate | 0.532    |
# | time/               |          |
# |    episodes         | 936      |
# |    fps              | 756      |
# |    time_elapsed     | 247      |
# |    total_timesteps  | 187200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00111  |
# |    n_updates        | 46549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 25.7     |
# |    exploration_rate | 0.53     |
# | time/               |          |
# |    episodes         | 940      |
# |    fps              | 757      |
# |    time_elapsed     | 248      |
# |    total_timesteps  | 188000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000546 |
# |    n_updates        | 46749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 25.4     |
# |    exploration_rate | 0.528    |
# | time/               |          |
# |    episodes         | 944      |
# |    fps              | 757      |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 188800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000729 |
# |    n_updates        | 46949    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 25.3     |
# |    exploration_rate | 0.526    |
# | time/               |          |
# |    episodes         | 948      |
# |    fps              | 757      |
# |    time_elapsed     | 250      |
# |    total_timesteps  | 189600   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000733 |
# |    n_updates        | 47149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 24.9     |
# |    exploration_rate | 0.524    |
# | time/               |          |
# |    episodes         | 952      |
# |    fps              | 756      |
# |    time_elapsed     | 251      |
# |    total_timesteps  | 190400   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000504 |
# |    n_updates        | 47349    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 24.5     |
# |    exploration_rate | 0.522    |
# | time/               |          |
# |    episodes         | 956      |
# |    fps              | 756      |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 191200   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00064  |
# |    n_updates        | 47549    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 24.6     |
# |    exploration_rate | 0.52     |
# | time/               |          |
# |    episodes         | 960      |
# |    fps              | 756      |
# |    time_elapsed     | 253      |
# |    total_timesteps  | 192000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000712 |
# |    n_updates        | 47749    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 24.5     |
# |    exploration_rate | 0.518    |
# | time/               |          |
# |    episodes         | 964      |
# |    fps              | 757      |
# |    time_elapsed     | 254      |
# |    total_timesteps  | 192761   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000599 |
# |    n_updates        | 47940    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 24.6     |
# |    exploration_rate | 0.516    |
# | time/               |          |
# |    episodes         | 968      |
# |    fps              | 757      |
# |    time_elapsed     | 255      |
# |    total_timesteps  | 193561   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000429 |
# |    n_updates        | 48140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 24.7     |
# |    exploration_rate | 0.514    |
# | time/               |          |
# |    episodes         | 972      |
# |    fps              | 757      |
# |    time_elapsed     | 256      |
# |    total_timesteps  | 194361   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00069  |
# |    n_updates        | 48340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 24.7     |
# |    exploration_rate | 0.512    |
# | time/               |          |
# |    episodes         | 976      |
# |    fps              | 758      |
# |    time_elapsed     | 257      |
# |    total_timesteps  | 195161   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00265  |
# |    n_updates        | 48540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 24.8     |
# |    exploration_rate | 0.51     |
# | time/               |          |
# |    episodes         | 980      |
# |    fps              | 758      |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 195961   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000645 |
# |    n_updates        | 48740    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 25.1     |
# |    exploration_rate | 0.508    |
# | time/               |          |
# |    episodes         | 984      |
# |    fps              | 758      |
# |    time_elapsed     | 259      |
# |    total_timesteps  | 196690   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0012   |
# |    n_updates        | 48922    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.506    |
# | time/               |          |
# |    episodes         | 988      |
# |    fps              | 759      |
# |    time_elapsed     | 260      |
# |    total_timesteps  | 197476   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000552 |
# |    n_updates        | 49118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 24.4     |
# |    exploration_rate | 0.504    |
# | time/               |          |
# |    episodes         | 992      |
# |    fps              | 759      |
# |    time_elapsed     | 261      |
# |    total_timesteps  | 198239   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00156  |
# |    n_updates        | 49309    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 24.3     |
# |    exploration_rate | 0.502    |
# | time/               |          |
# |    episodes         | 996      |
# |    fps              | 759      |
# |    time_elapsed     | 262      |
# |    total_timesteps  | 199039   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00115  |
# |    n_updates        | 49509    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 24       |
# |    exploration_rate | 0.5      |
# | time/               |          |
# |    episodes         | 1000     |
# |    fps              | 759      |
# |    time_elapsed     | 263      |
# |    total_timesteps  | 199839   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000493 |
# |    n_updates        | 49709    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.498    |
# | time/               |          |
# |    episodes         | 1004     |
# |    fps              | 758      |
# |    time_elapsed     | 264      |
# |    total_timesteps  | 200639   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000923 |
# |    n_updates        | 49909    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 22.4     |
# |    exploration_rate | 0.496    |
# | time/               |          |
# |    episodes         | 1008     |
# |    fps              | 758      |
# |    time_elapsed     | 265      |
# |    total_timesteps  | 201403   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00253  |
# |    n_updates        | 50100    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 22.3     |
# |    exploration_rate | 0.494    |
# | time/               |          |
# |    episodes         | 1012     |
# |    fps              | 758      |
# |    time_elapsed     | 266      |
# |    total_timesteps  | 202201   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000767 |
# |    n_updates        | 50300    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.492    |
# | time/               |          |
# |    episodes         | 1016     |
# |    fps              | 759      |
# |    time_elapsed     | 267      |
# |    total_timesteps  | 203001   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00108  |
# |    n_updates        | 50500    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 22.2     |
# |    exploration_rate | 0.491    |
# | time/               |          |
# |    episodes         | 1020     |
# |    fps              | 759      |
# |    time_elapsed     | 268      |
# |    total_timesteps  | 203762   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000464 |
# |    n_updates        | 50690    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.489    |
# | time/               |          |
# |    episodes         | 1024     |
# |    fps              | 760      |
# |    time_elapsed     | 269      |
# |    total_timesteps  | 204534   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000651 |
# |    n_updates        | 50883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 21.7     |
# |    exploration_rate | 0.487    |
# | time/               |          |
# |    episodes         | 1028     |
# |    fps              | 760      |
# |    time_elapsed     | 269      |
# |    total_timesteps  | 205334   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00043  |
# |    n_updates        | 51083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.485    |
# | time/               |          |
# |    episodes         | 1032     |
# |    fps              | 761      |
# |    time_elapsed     | 270      |
# |    total_timesteps  | 206134   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000984 |
# |    n_updates        | 51283    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.483    |
# | time/               |          |
# |    episodes         | 1036     |
# |    fps              | 761      |
# |    time_elapsed     | 271      |
# |    total_timesteps  | 206934   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00103  |
# |    n_updates        | 51483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.481    |
# | time/               |          |
# |    episodes         | 1040     |
# |    fps              | 761      |
# |    time_elapsed     | 272      |
# |    total_timesteps  | 207734   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000639 |
# |    n_updates        | 51683    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.479    |
# | time/               |          |
# |    episodes         | 1044     |
# |    fps              | 762      |
# |    time_elapsed     | 273      |
# |    total_timesteps  | 208534   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000674 |
# |    n_updates        | 51883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 21.6     |
# |    exploration_rate | 0.477    |
# | time/               |          |
# |    episodes         | 1048     |
# |    fps              | 762      |
# |    time_elapsed     | 274      |
# |    total_timesteps  | 209334   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000782 |
# |    n_updates        | 52083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.475    |
# | time/               |          |
# |    episodes         | 1052     |
# |    fps              | 762      |
# |    time_elapsed     | 275      |
# |    total_timesteps  | 210134   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00038  |
# |    n_updates        | 52283    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 21       |
# |    exploration_rate | 0.473    |
# | time/               |          |
# |    episodes         | 1056     |
# |    fps              | 762      |
# |    time_elapsed     | 276      |
# |    total_timesteps  | 210934   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000754 |
# |    n_updates        | 52483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 197      |
# |    ep_rew_mean      | 20.4     |
# |    exploration_rate | 0.471    |
# | time/               |          |
# |    episodes         | 1060     |
# |    fps              | 761      |
# |    time_elapsed     | 277      |
# |    total_timesteps  | 211734   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000494 |
# |    n_updates        | 52683    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 20.3     |
# |    exploration_rate | 0.469    |
# | time/               |          |
# |    episodes         | 1064     |
# |    fps              | 762      |
# |    time_elapsed     | 278      |
# |    total_timesteps  | 212534   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000383 |
# |    n_updates        | 52883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 20       |
# |    exploration_rate | 0.467    |
# | time/               |          |
# |    episodes         | 1068     |
# |    fps              | 762      |
# |    time_elapsed     | 279      |
# |    total_timesteps  | 213334   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000706 |
# |    n_updates        | 53083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 19.8     |
# |    exploration_rate | 0.465    |
# | time/               |          |
# |    episodes         | 1072     |
# |    fps              | 763      |
# |    time_elapsed     | 280      |
# |    total_timesteps  | 214134   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000893 |
# |    n_updates        | 53283    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 19.3     |
# |    exploration_rate | 0.463    |
# | time/               |          |
# |    episodes         | 1076     |
# |    fps              | 763      |
# |    time_elapsed     | 281      |
# |    total_timesteps  | 214934   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000726 |
# |    n_updates        | 53483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 19.1     |
# |    exploration_rate | 0.461    |
# | time/               |          |
# |    episodes         | 1080     |
# |    fps              | 763      |
# |    time_elapsed     | 282      |
# |    total_timesteps  | 215734   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000978 |
# |    n_updates        | 53683    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 198      |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.459    |
# | time/               |          |
# |    episodes         | 1084     |
# |    fps              | 764      |
# |    time_elapsed     | 283      |
# |    total_timesteps  | 216534   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000735 |
# |    n_updates        | 53883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.457    |
# | time/               |          |
# |    episodes         | 1088     |
# |    fps              | 764      |
# |    time_elapsed     | 284      |
# |    total_timesteps  | 217334   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000901 |
# |    n_updates        | 54083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.455    |
# | time/               |          |
# |    episodes         | 1092     |
# |    fps              | 764      |
# |    time_elapsed     | 285      |
# |    total_timesteps  | 218134   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000641 |
# |    n_updates        | 54283    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.453    |
# | time/               |          |
# |    episodes         | 1096     |
# |    fps              | 765      |
# |    time_elapsed     | 286      |
# |    total_timesteps  | 218934   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0014   |
# |    n_updates        | 54483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 17.9     |
# |    exploration_rate | 0.451    |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 765      |
# |    time_elapsed     | 287      |
# |    total_timesteps  | 219734   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000453 |
# |    n_updates        | 54683    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.449    |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 765      |
# |    time_elapsed     | 288      |
# |    total_timesteps  | 220534   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000811 |
# |    n_updates        | 54883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.447    |
# | time/               |          |
# |    episodes         | 1108     |
# |    fps              | 764      |
# |    time_elapsed     | 289      |
# |    total_timesteps  | 221334   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000782 |
# |    n_updates        | 55083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.445    |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 764      |
# |    time_elapsed     | 290      |
# |    total_timesteps  | 222134   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000655 |
# |    n_updates        | 55283    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 199      |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.443    |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 764      |
# |    time_elapsed     | 291      |
# |    total_timesteps  | 222934   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000421 |
# |    n_updates        | 55483    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.441    |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 765      |
# |    time_elapsed     | 292      |
# |    total_timesteps  | 223734   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00034  |
# |    n_updates        | 55683    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.439    |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 765      |
# |    time_elapsed     | 293      |
# |    total_timesteps  | 224534   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000383 |
# |    n_updates        | 55883    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.437    |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 765      |
# |    time_elapsed     | 294      |
# |    total_timesteps  | 225334   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000675 |
# |    n_updates        | 56083    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.435    |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 765      |
# |    time_elapsed     | 295      |
# |    total_timesteps  | 226134   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00036  |
# |    n_updates        | 56283    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 19.4     |
# |    exploration_rate | 0.433    |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 766      |
# |    time_elapsed     | 296      |
# |    total_timesteps  | 226926   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000453 |
# |    n_updates        | 56481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.431    |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 766      |
# |    time_elapsed     | 297      |
# |    total_timesteps  | 227726   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000817 |
# |    n_updates        | 56681    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 21.1     |
# |    exploration_rate | 0.429    |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 766      |
# |    time_elapsed     | 298      |
# |    total_timesteps  | 228526   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000264 |
# |    n_updates        | 56881    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 21.3     |
# |    exploration_rate | 0.427    |
# | time/               |          |
# |    episodes         | 1148     |
# |    fps              | 767      |
# |    time_elapsed     | 298      |
# |    total_timesteps  | 229326   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000702 |
# |    n_updates        | 57081    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 21.9     |
# |    exploration_rate | 0.425    |
# | time/               |          |
# |    episodes         | 1152     |
# |    fps              | 767      |
# |    time_elapsed     | 299      |
# |    total_timesteps  | 230125   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000809 |
# |    n_updates        | 57281    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.423    |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 766      |
# |    time_elapsed     | 301      |
# |    total_timesteps  | 230925   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00111  |
# |    n_updates        | 57481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 22.5     |
# |    exploration_rate | 0.421    |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 766      |
# |    time_elapsed     | 302      |
# |    total_timesteps  | 231725   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000393 |
# |    n_updates        | 57681    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 22.6     |
# |    exploration_rate | 0.419    |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 766      |
# |    time_elapsed     | 303      |
# |    total_timesteps  | 232525   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00991  |
# |    n_updates        | 57881    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.417    |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 766      |
# |    time_elapsed     | 304      |
# |    total_timesteps  | 233325   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000658 |
# |    n_updates        | 58081    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 22.7     |
# |    exploration_rate | 0.415    |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 767      |
# |    time_elapsed     | 305      |
# |    total_timesteps  | 234125   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00095  |
# |    n_updates        | 58281    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.413    |
# | time/               |          |
# |    episodes         | 1176     |
# |    fps              | 767      |
# |    time_elapsed     | 306      |
# |    total_timesteps  | 234925   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00116  |
# |    n_updates        | 58481    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 23.2     |
# |    exploration_rate | 0.411    |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 767      |
# |    time_elapsed     | 307      |
# |    total_timesteps  | 235725   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00059  |
# |    n_updates        | 58681    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 200      |
# |    ep_rew_mean      | 23.4     |
# |    exploration_rate | 0.409    |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 767      |
# |    time_elapsed     | 308      |
# |    total_timesteps  | 236525   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000673 |
# |    n_updates        | 58881    |
# ----------------------------------
# ...
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000254 |
# |    n_updates        | 94986    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 49.3     |
# |    exploration_rate | 0.0461   |
# | time/               |          |
# |    episodes         | 2036     |
# |    fps              | 761      |
# |    time_elapsed     | 500      |
# |    total_timesteps  | 381548   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00118  |
# |    n_updates        | 95136    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 49.1     |
# |    exploration_rate | 0.0447   |
# | time/               |          |
# |    episodes         | 2040     |
# |    fps              | 761      |
# |    time_elapsed     | 501      |
# |    total_timesteps  | 382113   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000689 |
# |    n_updates        | 95278    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 49       |
# |    exploration_rate | 0.0431   |
# | time/               |          |
# |    episodes         | 2044     |
# |    fps              | 760      |
# |    time_elapsed     | 503      |
# |    total_timesteps  | 382741   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00176  |
# |    n_updates        | 95435    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 48.8     |
# |    exploration_rate | 0.0415   |
# | time/               |          |
# |    episodes         | 2048     |
# |    fps              | 760      |
# |    time_elapsed     | 504      |
# |    total_timesteps  | 383388   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000503 |
# |    n_updates        | 95596    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 49       |
# |    exploration_rate | 0.04     |
# | time/               |          |
# |    episodes         | 2052     |
# |    fps              | 759      |
# |    time_elapsed     | 505      |
# |    total_timesteps  | 384019   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000989 |
# |    n_updates        | 95754    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 48.9     |
# |    exploration_rate | 0.0385   |
# | time/               |          |
# |    episodes         | 2056     |
# |    fps              | 759      |
# |    time_elapsed     | 506      |
# |    total_timesteps  | 384581   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000642 |
# |    n_updates        | 95895    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 49       |
# |    exploration_rate | 0.0369   |
# | time/               |          |
# |    episodes         | 2060     |
# |    fps              | 759      |
# |    time_elapsed     | 507      |
# |    total_timesteps  | 385250   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000807 |
# |    n_updates        | 96062    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 49.1     |
# |    exploration_rate | 0.0353   |
# | time/               |          |
# |    episodes         | 2064     |
# |    fps              | 759      |
# |    time_elapsed     | 508      |
# |    total_timesteps  | 385894   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000607 |
# |    n_updates        | 96223    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 48.9     |
# |    exploration_rate | 0.0338   |
# | time/               |          |
# |    episodes         | 2068     |
# |    fps              | 759      |
# |    time_elapsed     | 509      |
# |    total_timesteps  | 386499   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000638 |
# |    n_updates        | 96374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 48.6     |
# |    exploration_rate | 0.0323   |
# | time/               |          |
# |    episodes         | 2072     |
# |    fps              | 759      |
# |    time_elapsed     | 509      |
# |    total_timesteps  | 387098   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00653  |
# |    n_updates        | 96524    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 48.5     |
# |    exploration_rate | 0.0308   |
# | time/               |          |
# |    episodes         | 2076     |
# |    fps              | 759      |
# |    time_elapsed     | 510      |
# |    total_timesteps  | 387662   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000652 |
# |    n_updates        | 96665    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | 48.4     |
# |    exploration_rate | 0.0292   |
# | time/               |          |
# |    episodes         | 2080     |
# |    fps              | 759      |
# |    time_elapsed     | 511      |
# |    total_timesteps  | 388318   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000349 |
# |    n_updates        | 96829    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 48.7     |
# |    exploration_rate | 0.0277   |
# | time/               |          |
# |    episodes         | 2084     |
# |    fps              | 759      |
# |    time_elapsed     | 512      |
# |    total_timesteps  | 388926   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000787 |
# |    n_updates        | 96981    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 48.9     |
# |    exploration_rate | 0.0261   |
# | time/               |          |
# |    episodes         | 2088     |
# |    fps              | 759      |
# |    time_elapsed     | 513      |
# |    total_timesteps  | 389565   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00248  |
# |    n_updates        | 97141    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 48.6     |
# |    exploration_rate | 0.0246   |
# | time/               |          |
# |    episodes         | 2092     |
# |    fps              | 759      |
# |    time_elapsed     | 513      |
# |    total_timesteps  | 390169   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00207  |
# |    n_updates        | 97292    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 49.2     |
# |    exploration_rate | 0.0229   |
# | time/               |          |
# |    episodes         | 2096     |
# |    fps              | 759      |
# |    time_elapsed     | 514      |
# |    total_timesteps  | 390856   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000816 |
# |    n_updates        | 97463    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 49.2     |
# |    exploration_rate | 0.0213   |
# | time/               |          |
# |    episodes         | 2100     |
# |    fps              | 759      |
# |    time_elapsed     | 515      |
# |    total_timesteps  | 391496   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000356 |
# |    n_updates        | 97623    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 49.3     |
# |    exploration_rate | 0.0196   |
# | time/               |          |
# |    episodes         | 2104     |
# |    fps              | 758      |
# |    time_elapsed     | 516      |
# |    total_timesteps  | 392144   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000912 |
# |    n_updates        | 97785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 49.2     |
# |    exploration_rate | 0.0181   |
# | time/               |          |
# |    episodes         | 2108     |
# |    fps              | 758      |
# |    time_elapsed     | 517      |
# |    total_timesteps  | 392744   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000518 |
# |    n_updates        | 97935    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 49.1     |
# |    exploration_rate | 0.0166   |
# | time/               |          |
# |    episodes         | 2112     |
# |    fps              | 758      |
# |    time_elapsed     | 518      |
# |    total_timesteps  | 393344   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00287  |
# |    n_updates        | 98085    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 49.2     |
# |    exploration_rate | 0.0151   |
# | time/               |          |
# |    episodes         | 2116     |
# |    fps              | 758      |
# |    time_elapsed     | 519      |
# |    total_timesteps  | 393951   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00151  |
# |    n_updates        | 98237    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 49       |
# |    exploration_rate | 0.0136   |
# | time/               |          |
# |    episodes         | 2120     |
# |    fps              | 758      |
# |    time_elapsed     | 520      |
# |    total_timesteps  | 394558   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000585 |
# |    n_updates        | 98389    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 48.7     |
# |    exploration_rate | 0.0121   |
# | time/               |          |
# |    episodes         | 2124     |
# |    fps              | 758      |
# |    time_elapsed     | 521      |
# |    total_timesteps  | 395150   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000556 |
# |    n_updates        | 98537    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 48.6     |
# |    exploration_rate | 0.0105   |
# | time/               |          |
# |    episodes         | 2128     |
# |    fps              | 758      |
# |    time_elapsed     | 521      |
# |    total_timesteps  | 395790   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000338 |
# |    n_updates        | 98697    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 48.6     |
# |    exploration_rate | 0.00899  |
# | time/               |          |
# |    episodes         | 2132     |
# |    fps              | 758      |
# |    time_elapsed     | 522      |
# |    total_timesteps  | 396404   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000587 |
# |    n_updates        | 98850    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 48.5     |
# |    exploration_rate | 0.00749  |
# | time/               |          |
# |    episodes         | 2136     |
# |    fps              | 758      |
# |    time_elapsed     | 523      |
# |    total_timesteps  | 397004   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000338 |
# |    n_updates        | 99000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 48.6     |
# |    exploration_rate | 0.00609  |
# | time/               |          |
# |    episodes         | 2140     |
# |    fps              | 758      |
# |    time_elapsed     | 524      |
# |    total_timesteps  | 397562   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000213 |
# |    n_updates        | 99140    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 48.5     |
# |    exploration_rate | 0.0047   |
# | time/               |          |
# |    episodes         | 2144     |
# |    fps              | 758      |
# |    time_elapsed     | 524      |
# |    total_timesteps  | 398120   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.000347 |
# |    n_updates        | 99279    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 49       |
# |    exploration_rate | 0.00305  |
# | time/               |          |
# |    episodes         | 2148     |
# |    fps              | 758      |
# |    time_elapsed     | 525      |
# |    total_timesteps  | 398781   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00167  |
# |    n_updates        | 99445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 49.2     |
# |    exploration_rate | 0.00145  |
# | time/               |          |
# |    episodes         | 2152     |
# |    fps              | 758      |
# |    time_elapsed     | 526      |
# |    total_timesteps  | 399421   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00368  |
# |    n_updates        | 99605    |
# ----------------------------------
# Mean reward: 47.1526101 and Standard Deviation: 18.71678144977231

# %%
training_values_1=[]
log_dir = "/tmp/gym/"
os.makedirs(log_dir, exist_ok=True)
scalar_weight=np.array([0.05,0.95])
steps = 400000
env = mo.LinearReward(mo.make(environment, render_mode="rgb_array"), weight=scalar_weight) #Since 2nd objective is positive, will give it same weightage
env = Monitor(env, log_dir)
#env = mo.LinearReward(mo.make("mo-mountaincar-velocity", render_mode="rgb_array"), weight=np.array([0.9, 0.1]))

values_1 = []

print("Action space:", env.action_space)
# for action_index in range(env.action_space.n):
#         print(f"Action index {action_index} corresponds to action: {env.unwrapped.get_action_meanings()[action_index]}")4

agent = sb3.A2C(policy="MlpPolicy",
            env=env,
            seed=0,
            learning_rate=0.0001,
            gamma=0.9,
            gae_lambda=1.0,  # Set to 1.0 for no advantage estimation (just discounted reward)
            max_grad_norm=5,
            verbose=1)
callback = SaveOnBestTrainingRewardCallback(check_freq=1000, log_dir=log_dir, reward_dim=env.unwrapped.reward_dim)
agent.learn(total_timesteps=steps, callback=callback) #, callback=callback #200000
#,progress_bar=True , callback=callback

#Can save each model I learn and see which one is the best
#timesteps is 200000
agent.save(f"A2C-{environment}-{scalar_weight}-{steps}")
mean_reward, std_reward = evaluate_policy(agent, agent.get_env(), n_eval_episodes=10) #Originally 10
print(f"Mean reward: {mean_reward} and Standard Deviation: {std_reward}")
# Out:
# Streaming output truncated to the last 5000 lines.
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.9     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 50700    |
# |    time_elapsed       | 624      |
# |    total_timesteps    | 253500   |
# | train/                |          |
# |    entropy_loss       | -0.0231  |
# |    explained_variance | 0.219    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 50699    |
# |    policy_loss        | 0.000577 |
# |    value_loss         | 0.0375   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.6      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 50800     |
# |    time_elapsed       | 625       |
# |    total_timesteps    | 254000    |
# | train/                |           |
# |    entropy_loss       | -0.016    |
# |    explained_variance | -0.0582   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 50799     |
# |    policy_loss        | -0.000278 |
# |    value_loss         | 0.0243    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.4     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 50900    |
# |    time_elapsed       | 626      |
# |    total_timesteps    | 254500   |
# | train/                |          |
# |    entropy_loss       | -0.021   |
# |    explained_variance | 0.23     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 50899    |
# |    policy_loss        | 0.00081  |
# |    value_loss         | 0.0908   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.1      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 51000     |
# |    time_elapsed       | 627       |
# |    total_timesteps    | 255000    |
# | train/                |           |
# |    entropy_loss       | -0.00964  |
# |    explained_variance | -0.359    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 50999     |
# |    policy_loss        | -0.000233 |
# |    value_loss         | 0.0456    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13       |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 51100    |
# |    time_elapsed       | 628      |
# |    total_timesteps    | 255500   |
# | train/                |          |
# |    entropy_loss       | -0.0189  |
# |    explained_variance | 0.299    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 51099    |
# |    policy_loss        | 0.37     |
# |    value_loss         | 0.043    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.2      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 51200     |
# |    time_elapsed       | 629       |
# |    total_timesteps    | 256000    |
# | train/                |           |
# |    entropy_loss       | -0.0126   |
# |    explained_variance | -0.121    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 51199     |
# |    policy_loss        | -0.000455 |
# |    value_loss         | 0.101     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.4      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 51300     |
# |    time_elapsed       | 631       |
# |    total_timesteps    | 256500    |
# | train/                |           |
# |    entropy_loss       | -0.022    |
# |    explained_variance | -1.92     |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 51299     |
# |    policy_loss        | -0.000101 |
# |    value_loss         | 0.00141   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.4      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 51400     |
# |    time_elapsed       | 632       |
# |    total_timesteps    | 257000    |
# | train/                |           |
# |    entropy_loss       | -0.0198   |
# |    explained_variance | -0.0327   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 51399     |
# |    policy_loss        | -0.000492 |
# |    value_loss         | 0.046     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.3     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 51500    |
# |    time_elapsed       | 633      |
# |    total_timesteps    | 257500   |
# | train/                |          |
# |    entropy_loss       | -0.0307  |
# |    explained_variance | 0.18     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 51499    |
# |    policy_loss        | 0.00167  |
# |    value_loss         | 0.157    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.4      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 51600     |
# |    time_elapsed       | 635       |
# |    total_timesteps    | 258000    |
# | train/                |           |
# |    entropy_loss       | -0.0163   |
# |    explained_variance | -0.102    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 51599     |
# |    policy_loss        | -0.000581 |
# |    value_loss         | 0.0939    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.3     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 51700    |
# |    time_elapsed       | 636      |
# |    total_timesteps    | 258500   |
# | train/                |          |
# |    entropy_loss       | -0.0241  |
# |    explained_variance | 0.39     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 51699    |
# |    policy_loss        | 0.000393 |
# |    value_loss         | 0.0163   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.2     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 51800    |
# |    time_elapsed       | 637      |
# |    total_timesteps    | 259000   |
# | train/                |          |
# |    entropy_loss       | -0.0213  |
# |    explained_variance | 0.00347  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 51799    |
# |    policy_loss        | -0.00051 |
# |    value_loss         | 0.0401   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.1     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 51900    |
# |    time_elapsed       | 638      |
# |    total_timesteps    | 259500   |
# | train/                |          |
# |    entropy_loss       | -0.0259  |
# |    explained_variance | 0.199    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 51899    |
# |    policy_loss        | 0.00098  |
# |    value_loss         | 0.0824   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.6      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 52000     |
# |    time_elapsed       | 639       |
# |    total_timesteps    | 260000    |
# | train/                |           |
# |    entropy_loss       | -0.0124   |
# |    explained_variance | -0.438    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 51999     |
# |    policy_loss        | -0.000309 |
# |    value_loss         | 0.045     |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.8     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 52100    |
# |    time_elapsed       | 640      |
# |    total_timesteps    | 260500   |
# | train/                |          |
# |    entropy_loss       | -0.0256  |
# |    explained_variance | 0.268    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 52099    |
# |    policy_loss        | 0.000615 |
# |    value_loss         | 0.0337   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.8      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 52200     |
# |    time_elapsed       | 642       |
# |    total_timesteps    | 261000    |
# | train/                |           |
# |    entropy_loss       | -0.0148   |
# |    explained_variance | -0.0396   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 52199     |
# |    policy_loss        | -0.000356 |
# |    value_loss         | 0.0462    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.5     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 52300    |
# |    time_elapsed       | 643      |
# |    total_timesteps    | 261500   |
# | train/                |          |
# |    entropy_loss       | -0.0197  |
# |    explained_variance | 0.443    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 52299    |
# |    policy_loss        | 0.000233 |
# |    value_loss         | 0.00897  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.6      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 52400     |
# |    time_elapsed       | 644       |
# |    total_timesteps    | 262000    |
# | train/                |           |
# |    entropy_loss       | -0.0112   |
# |    explained_variance | -0.245    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 52399     |
# |    policy_loss        | -0.000267 |
# |    value_loss         | 0.0442    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.5     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 52500    |
# |    time_elapsed       | 646      |
# |    total_timesteps    | 262500   |
# | train/                |          |
# |    entropy_loss       | -0.0187  |
# |    explained_variance | 0.82     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 52499    |
# |    policy_loss        | 4.85e-05 |
# |    value_loss         | 0.000417 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.6      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 52600     |
# |    time_elapsed       | 647       |
# |    total_timesteps    | 263000    |
# | train/                |           |
# |    entropy_loss       | -0.0132   |
# |    explained_variance | -0.153    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 52599     |
# |    policy_loss        | -0.000448 |
# |    value_loss         | 0.0868    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.6     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 52700    |
# |    time_elapsed       | 648      |
# |    total_timesteps    | 263500   |
# | train/                |          |
# |    entropy_loss       | -0.0196  |
# |    explained_variance | 0.515    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 52699    |
# |    policy_loss        | 0.000176 |
# |    value_loss         | 0.00499  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.3      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 52800     |
# |    time_elapsed       | 649       |
# |    total_timesteps    | 264000    |
# | train/                |           |
# |    entropy_loss       | -0.0159   |
# |    explained_variance | 0.00117   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 52799     |
# |    policy_loss        | -0.000128 |
# |    value_loss         | 0.00533   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.3     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 52900    |
# |    time_elapsed       | 650      |
# |    total_timesteps    | 264500   |
# | train/                |          |
# |    entropy_loss       | -0.0199  |
# |    explained_variance | 0.624    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 52899    |
# |    policy_loss        | 0.000109 |
# |    value_loss         | 0.00193  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.9      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 53000     |
# |    time_elapsed       | 651       |
# |    total_timesteps    | 265000    |
# | train/                |           |
# |    entropy_loss       | -0.0163   |
# |    explained_variance | -0.054    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 52999     |
# |    policy_loss        | -0.000159 |
# |    value_loss         | 0.00812   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.8     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 53100    |
# |    time_elapsed       | 653      |
# |    total_timesteps    | 265500   |
# | train/                |          |
# |    entropy_loss       | -0.0205  |
# |    explained_variance | 0.972    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 53099    |
# |    policy_loss        | 1.54e-05 |
# |    value_loss         | 3.47e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.5     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 53200    |
# |    time_elapsed       | 654      |
# |    total_timesteps    | 266000   |
# | train/                |          |
# |    entropy_loss       | -0.00896 |
# |    explained_variance | 0.52     |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 53199    |
# |    policy_loss        | 4.95e-06 |
# |    value_loss         | 0.00106  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.4     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 53300    |
# |    time_elapsed       | 655      |
# |    total_timesteps    | 266500   |
# | train/                |          |
# |    entropy_loss       | -0.0187  |
# |    explained_variance | 0.256    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 53299    |
# |    policy_loss        | 0.000633 |
# |    value_loss         | 0.0734   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.4      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 53400     |
# |    time_elapsed       | 657       |
# |    total_timesteps    | 267000    |
# | train/                |           |
# |    entropy_loss       | -0.0129   |
# |    explained_variance | -0.0866   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 53399     |
# |    policy_loss        | -0.000346 |
# |    value_loss         | 0.0596    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.5     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 53500    |
# |    time_elapsed       | 658      |
# |    total_timesteps    | 267500   |
# | train/                |          |
# |    entropy_loss       | -0.0183  |
# |    explained_variance | 0.725    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 53499    |
# |    policy_loss        | 5.77e-05 |
# |    value_loss         | 0.000623 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.7      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 53600     |
# |    time_elapsed       | 659       |
# |    total_timesteps    | 268000    |
# | train/                |           |
# |    entropy_loss       | -0.0112   |
# |    explained_variance | -0.243    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 53599     |
# |    policy_loss        | -0.000321 |
# |    value_loss         | 0.0626    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.6     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 53700    |
# |    time_elapsed       | 660      |
# |    total_timesteps    | 268500   |
# | train/                |          |
# |    entropy_loss       | -0.0189  |
# |    explained_variance | 0.334    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 53699    |
# |    policy_loss        | 0.000395 |
# |    value_loss         | 0.0285   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.4     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 53800    |
# |    time_elapsed       | 661      |
# |    total_timesteps    | 269000   |
# | train/                |          |
# |    entropy_loss       | -0.0149  |
# |    explained_variance | 0.0312   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 53799    |
# |    policy_loss        | -0.00021 |
# |    value_loss         | 0.0155   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.6     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 53900    |
# |    time_elapsed       | 662      |
# |    total_timesteps    | 269500   |
# | train/                |          |
# |    entropy_loss       | -0.0156  |
# |    explained_variance | 0.529    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 53899    |
# |    policy_loss        | 0.000114 |
# |    value_loss         | 0.0036   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.5      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 54000     |
# |    time_elapsed       | 664       |
# |    total_timesteps    | 270000    |
# | train/                |           |
# |    entropy_loss       | -0.0143   |
# |    explained_variance | -0.0297   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 53999     |
# |    policy_loss        | -0.000227 |
# |    value_loss         | 0.0206    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.6     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 54100    |
# |    time_elapsed       | 665      |
# |    total_timesteps    | 270500   |
# | train/                |          |
# |    entropy_loss       | -0.0171  |
# |    explained_variance | 0.417    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 54099    |
# |    policy_loss        | 0.000221 |
# |    value_loss         | 0.0114   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.5      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 54200     |
# |    time_elapsed       | 666       |
# |    total_timesteps    | 271000    |
# | train/                |           |
# |    entropy_loss       | -0.00882  |
# |    explained_variance | -0.185    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 54199     |
# |    policy_loss        | -0.000255 |
# |    value_loss         | 0.0687    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.4     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 54300    |
# |    time_elapsed       | 668      |
# |    total_timesteps    | 271500   |
# | train/                |          |
# |    entropy_loss       | -0.0138  |
# |    explained_variance | 0.193    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 54299    |
# |    policy_loss        | 0.000487 |
# |    value_loss         | 0.0857   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.3     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 54400    |
# |    time_elapsed       | 669      |
# |    total_timesteps    | 272000   |
# | train/                |          |
# |    entropy_loss       | -0.00808 |
# |    explained_variance | -0.106   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 54399    |
# |    policy_loss        | -0.00025 |
# |    value_loss         | 0.0829   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.4      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 54500     |
# |    time_elapsed       | 670       |
# |    total_timesteps    | 272500    |
# | train/                |           |
# |    entropy_loss       | -0.0114   |
# |    explained_variance | 0.152     |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 54499     |
# |    policy_loss        | -1.67e-06 |
# |    value_loss         | 1.85e-05  |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.3     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 54600    |
# |    time_elapsed       | 671      |
# |    total_timesteps    | 273000   |
# | train/                |          |
# |    entropy_loss       | -0.00591 |
# |    explained_variance | 0.509    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 54599    |
# |    policy_loss        | 2.23e-06 |
# |    value_loss         | 0.0011   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.4     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 54700    |
# |    time_elapsed       | 672      |
# |    total_timesteps    | 273500   |
# | train/                |          |
# |    entropy_loss       | -0.013   |
# |    explained_variance | 0.447    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 54699    |
# |    policy_loss        | 8.31e-05 |
# |    value_loss         | 0.00283  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.4      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 54800     |
# |    time_elapsed       | 673       |
# |    total_timesteps    | 274000    |
# | train/                |           |
# |    entropy_loss       | -0.00686  |
# |    explained_variance | -0.356    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 54799     |
# |    policy_loss        | -0.000162 |
# |    value_loss         | 0.0473    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.7     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 54900    |
# |    time_elapsed       | 675      |
# |    total_timesteps    | 274500   |
# | train/                |          |
# |    entropy_loss       | -0.01    |
# |    explained_variance | -0.29    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 54899    |
# |    policy_loss        | -0.00014 |
# |    value_loss         | 0.0158   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.7      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 55000     |
# |    time_elapsed       | 676       |
# |    total_timesteps    | 275000    |
# | train/                |           |
# |    entropy_loss       | -0.00788  |
# |    explained_variance | -0.0722   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 54999     |
# |    policy_loss        | -0.000208 |
# |    value_loss         | 0.0651    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.9     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 55100    |
# |    time_elapsed       | 677      |
# |    total_timesteps    | 275500   |
# | train/                |          |
# |    entropy_loss       | -0.0113  |
# |    explained_variance | 0.694    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 55099    |
# |    policy_loss        | 4.02e-05 |
# |    value_loss         | 0.000918 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.8      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 55200     |
# |    time_elapsed       | 678       |
# |    total_timesteps    | 276000    |
# | train/                |           |
# |    entropy_loss       | -0.0103   |
# |    explained_variance | -0.0242   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 55199     |
# |    policy_loss        | -0.000251 |
# |    value_loss         | 0.0516    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.5     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 55300    |
# |    time_elapsed       | 680      |
# |    total_timesteps    | 276500   |
# | train/                |          |
# |    entropy_loss       | -0.0125  |
# |    explained_variance | 0.221    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 55299    |
# |    policy_loss        | 0.000408 |
# |    value_loss         | 0.0763   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.8      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 55400     |
# |    time_elapsed       | 681       |
# |    total_timesteps    | 277000    |
# | train/                |           |
# |    entropy_loss       | -0.00615  |
# |    explained_variance | -0.35     |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 55399     |
# |    policy_loss        | -0.000157 |
# |    value_loss         | 0.0562    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.1     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 55500    |
# |    time_elapsed       | 682      |
# |    total_timesteps    | 277500   |
# | train/                |          |
# |    entropy_loss       | -0.0109  |
# |    explained_variance | 0.489    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 55499    |
# |    policy_loss        | 8.22e-05 |
# |    value_loss         | 0.00423  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13        |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 55600     |
# |    time_elapsed       | 683       |
# |    total_timesteps    | 278000    |
# | train/                |           |
# |    entropy_loss       | -0.00757  |
# |    explained_variance | -0.208    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 55599     |
# |    policy_loss        | -0.000235 |
# |    value_loss         | 0.0813    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.3     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 55700    |
# |    time_elapsed       | 685      |
# |    total_timesteps    | 278500   |
# | train/                |          |
# |    entropy_loss       | -0.0145  |
# |    explained_variance | 0.125    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 55699    |
# |    policy_loss        | 0.000487 |
# |    value_loss         | 0.0756   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.5      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 55800     |
# |    time_elapsed       | 686       |
# |    total_timesteps    | 279000    |
# | train/                |           |
# |    entropy_loss       | -0.00678  |
# |    explained_variance | -0.254    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 55799     |
# |    policy_loss        | -0.000203 |
# |    value_loss         | 0.0775    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.6     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 55900    |
# |    time_elapsed       | 687      |
# |    total_timesteps    | 279500   |
# | train/                |          |
# |    entropy_loss       | -0.0141  |
# |    explained_variance | 0.233    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 55899    |
# |    policy_loss        | 0.000442 |
# |    value_loss         | 0.0675   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.6      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 56000     |
# |    time_elapsed       | 688       |
# |    total_timesteps    | 280000    |
# | train/                |           |
# |    entropy_loss       | -0.00529  |
# |    explained_variance | -1        |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 55999     |
# |    policy_loss        | -6.75e-05 |
# |    value_loss         | 0.0141    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.6     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 56100    |
# |    time_elapsed       | 689      |
# |    total_timesteps    | 280500   |
# | train/                |          |
# |    entropy_loss       | -0.0107  |
# |    explained_variance | 0.449    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 56099    |
# |    policy_loss        | 0.000105 |
# |    value_loss         | 0.00726  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.7      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 56200     |
# |    time_elapsed       | 691       |
# |    total_timesteps    | 281000    |
# | train/                |           |
# |    entropy_loss       | -0.00586  |
# |    explained_variance | 0.582     |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 56199     |
# |    policy_loss        | -1.48e-05 |
# |    value_loss         | 0.00107   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.8     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 56300    |
# |    time_elapsed       | 692      |
# |    total_timesteps    | 281500   |
# | train/                |          |
# |    entropy_loss       | -0.011   |
# |    explained_variance | 0.202    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 56299    |
# |    policy_loss        | 0.000311 |
# |    value_loss         | 0.059    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 14.2      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 56400     |
# |    time_elapsed       | 693       |
# |    total_timesteps    | 282000    |
# | train/                |           |
# |    entropy_loss       | -0.0054   |
# |    explained_variance | -1.13     |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 56399     |
# |    policy_loss        | -7.14e-05 |
# |    value_loss         | 0.0151    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 14.2     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 56500    |
# |    time_elapsed       | 694      |
# |    total_timesteps    | 282500   |
# | train/                |          |
# |    entropy_loss       | -0.0116  |
# |    explained_variance | 0.107    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 56499    |
# |    policy_loss        | 0.000331 |
# |    value_loss         | 0.0577   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 14.4      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 56600     |
# |    time_elapsed       | 696       |
# |    total_timesteps    | 283000    |
# | train/                |           |
# |    entropy_loss       | -0.00823  |
# |    explained_variance | -0.0399   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 56599     |
# |    policy_loss        | -0.000235 |
# |    value_loss         | 0.0755    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 14.7     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 56700    |
# |    time_elapsed       | 697      |
# |    total_timesteps    | 283500   |
# | train/                |          |
# |    entropy_loss       | -0.0123  |
# |    explained_variance | 0.0951   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 56699    |
# |    policy_loss        | 0.000382 |
# |    value_loss         | 0.067    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 15.1      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 56800     |
# |    time_elapsed       | 698       |
# |    total_timesteps    | 284000    |
# | train/                |           |
# |    entropy_loss       | -0.00818  |
# |    explained_variance | -0.0722   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 56799     |
# |    policy_loss        | -0.000247 |
# |    value_loss         | 0.0839    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 15.2     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 56900    |
# |    time_elapsed       | 699      |
# |    total_timesteps    | 284500   |
# | train/                |          |
# |    entropy_loss       | -0.0157  |
# |    explained_variance | 0.195    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 56899    |
# |    policy_loss        | 0.000696 |
# |    value_loss         | 0.129    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 15.7     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 57000    |
# |    time_elapsed       | 700      |
# |    total_timesteps    | 285000   |
# | train/                |          |
# |    entropy_loss       | -0.00825 |
# |    explained_variance | -0.087   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 56999    |
# |    policy_loss        | -0.00025 |
# |    value_loss         | 0.0825   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 16       |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 57100    |
# |    time_elapsed       | 702      |
# |    total_timesteps    | 285500   |
# | train/                |          |
# |    entropy_loss       | -0.0116  |
# |    explained_variance | 0.894    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 57099    |
# |    policy_loss        | 2.08e-05 |
# |    value_loss         | 0.000225 |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 16.2      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 57200     |
# |    time_elapsed       | 703       |
# |    total_timesteps    | 286000    |
# | train/                |           |
# |    entropy_loss       | -0.00933  |
# |    explained_variance | -0.0666   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 57199     |
# |    policy_loss        | -0.000259 |
# |    value_loss         | 0.0695    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 16.2     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 57300    |
# |    time_elapsed       | 705      |
# |    total_timesteps    | 286500   |
# | train/                |          |
# |    entropy_loss       | -0.0124  |
# |    explained_variance | 0.262    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 57299    |
# |    policy_loss        | 0.000473 |
# |    value_loss         | 0.104    |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 16        |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 57400     |
# |    time_elapsed       | 706       |
# |    total_timesteps    | 287000    |
# | train/                |           |
# |    entropy_loss       | -0.00998  |
# |    explained_variance | -0.0279   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 57399     |
# |    policy_loss        | -9.77e-05 |
# |    value_loss         | 0.009     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 16        |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 57500     |
# |    time_elapsed       | 707       |
# |    total_timesteps    | 287500    |
# | train/                |           |
# |    entropy_loss       | -0.00975  |
# |    explained_variance | -0.176    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 57499     |
# |    policy_loss        | -0.000195 |
# |    value_loss         | 0.0325    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 15.9      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 57600     |
# |    time_elapsed       | 708       |
# |    total_timesteps    | 288000    |
# | train/                |           |
# |    entropy_loss       | -0.00809  |
# |    explained_variance | -0.055    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 57599     |
# |    policy_loss        | -0.000173 |
# |    value_loss         | 0.0436    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 16       |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 57700    |
# |    time_elapsed       | 709      |
# |    total_timesteps    | 288500   |
# | train/                |          |
# |    entropy_loss       | -0.00969 |
# |    explained_variance | 0.573    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 57699    |
# |    policy_loss        | 6.64e-05 |
# |    value_loss         | 0.00369  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 16.2      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 57800     |
# |    time_elapsed       | 711       |
# |    total_timesteps    | 289000    |
# | train/                |           |
# |    entropy_loss       | -0.00721  |
# |    explained_variance | -0.146    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 57799     |
# |    policy_loss        | -0.000244 |
# |    value_loss         | 0.0992    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 16       |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 57900    |
# |    time_elapsed       | 712      |
# |    total_timesteps    | 289500   |
# | train/                |          |
# |    entropy_loss       | -0.0103  |
# |    explained_variance | 0.331    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 57899    |
# |    policy_loss        | 0.000234 |
# |    value_loss         | 0.0397   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 16.1      |
# | time/                 |           |
# |    fps                | 406       |
# |    iterations         | 58000     |
# |    time_elapsed       | 713       |
# |    total_timesteps    | 290000    |
# | train/                |           |
# |    entropy_loss       | -0.00692  |
# |    explained_variance | -0.146    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 57999     |
# |    policy_loss        | -0.000199 |
# |    value_loss         | 0.0749    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 16.2     |
# | time/                 |          |
# |    fps                | 406      |
# |    iterations         | 58100    |
# |    time_elapsed       | 714      |
# |    total_timesteps    | 290500   |
# | train/                |          |
# |    entropy_loss       | -0.011   |
# |    explained_variance | 0.416    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 58099    |
# |    policy_loss        | 0.000147 |
# |    value_loss         | 0.0136   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 16.3     |
# ...
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.4     |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 77600    |
# |    time_elapsed       | 957      |
# |    total_timesteps    | 388000   |
# | train/                |          |
# |    entropy_loss       | -0.016   |
# |    explained_variance | -0.0114  |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 77599    |
# |    policy_loss        | -0.00025 |
# |    value_loss         | 0.0203   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13.1     |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 77700    |
# |    time_elapsed       | 958      |
# |    total_timesteps    | 388500   |
# | train/                |          |
# |    entropy_loss       | -0.0251  |
# |    explained_variance | 0.227    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 77699    |
# |    policy_loss        | 0.000982 |
# |    value_loss         | 0.0891   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.3      |
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 77800     |
# |    time_elapsed       | 959       |
# |    total_timesteps    | 389000    |
# | train/                |           |
# |    entropy_loss       | -0.013    |
# |    explained_variance | -0.0933   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 77799     |
# |    policy_loss        | -0.000409 |
# |    value_loss         | 0.0793    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13       |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 77900    |
# |    time_elapsed       | 960      |
# |    total_timesteps    | 389500   |
# | train/                |          |
# |    entropy_loss       | -0.0198  |
# |    explained_variance | 0.242    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 77899    |
# |    policy_loss        | 0.000786 |
# |    value_loss         | 0.0992   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.2      |
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 78000     |
# |    time_elapsed       | 961       |
# |    total_timesteps    | 390000    |
# | train/                |           |
# |    entropy_loss       | -0.0107   |
# |    explained_variance | -0.1      |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 77999     |
# |    policy_loss        | -0.000377 |
# |    value_loss         | 0.103     |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.2      |
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 78100     |
# |    time_elapsed       | 963       |
# |    total_timesteps    | 390500    |
# | train/                |           |
# |    entropy_loss       | -0.0181   |
# |    explained_variance | -100      |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 78099     |
# |    policy_loss        | -5.74e-05 |
# |    value_loss         | 0.000667  |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13.2      |
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 78200     |
# |    time_elapsed       | 964       |
# |    total_timesteps    | 391000    |
# | train/                |           |
# |    entropy_loss       | -0.0142   |
# |    explained_variance | -0.19     |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 78199     |
# |    policy_loss        | -0.000479 |
# |    value_loss         | 0.0812    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13       |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 78300    |
# |    time_elapsed       | 965      |
# |    total_timesteps    | 391500   |
# | train/                |          |
# |    entropy_loss       | -0.023   |
# |    explained_variance | 0.221    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 78299    |
# |    policy_loss        | 0.000874 |
# |    value_loss         | 0.0854   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.7      |
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 78400     |
# |    time_elapsed       | 966       |
# |    total_timesteps    | 392000    |
# | train/                |           |
# |    entropy_loss       | -0.0165   |
# |    explained_variance | -0.0503   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 78399     |
# |    policy_loss        | -0.000221 |
# |    value_loss         | 0.0148    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.9      |
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 78500     |
# |    time_elapsed       | 968       |
# |    total_timesteps    | 392500    |
# | train/                |           |
# |    entropy_loss       | -0.0204   |
# |    explained_variance | -1.24     |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 78499     |
# |    policy_loss        | -0.000123 |
# |    value_loss         | 0.00249   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.8      |
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 78600     |
# |    time_elapsed       | 969       |
# |    total_timesteps    | 393000    |
# | train/                |           |
# |    entropy_loss       | -0.0151   |
# |    explained_variance | 0.0435    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 78599     |
# |    policy_loss        | -7.92e-05 |
# |    value_loss         | 0.00265   |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.9     |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 78700    |
# |    time_elapsed       | 970      |
# |    total_timesteps    | 393500   |
# | train/                |          |
# |    entropy_loss       | -0.0195  |
# |    explained_variance | 0.355    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 78699    |
# |    policy_loss        | 0.000348 |
# |    value_loss         | 0.0205   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.5      |
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 78800     |
# |    time_elapsed       | 971       |
# |    total_timesteps    | 394000    |
# | train/                |           |
# |    entropy_loss       | -0.0123   |
# |    explained_variance | -0.0943   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 78799     |
# |    policy_loss        | -0.000287 |
# |    value_loss         | 0.0455    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.9     |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 78900    |
# |    time_elapsed       | 972      |
# |    total_timesteps    | 394500   |
# | train/                |          |
# |    entropy_loss       | -0.0174  |
# |    explained_variance | 0.647    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 78899    |
# |    policy_loss        | 7.89e-05 |
# |    value_loss         | 0.00133  |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.7      |
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 79000     |
# |    time_elapsed       | 974       |
# |    total_timesteps    | 395000    |
# | train/                |           |
# |    entropy_loss       | -0.00989  |
# |    explained_variance | -0.326    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 78999     |
# |    policy_loss        | -0.000261 |
# |    value_loss         | 0.0538    |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.9      |
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 79100     |
# |    time_elapsed       | 975       |
# |    total_timesteps    | 395500    |
# | train/                |           |
# |    entropy_loss       | -0.0195   |
# |    explained_variance | -0.376    |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 79099     |
# |    policy_loss        | -0.000229 |
# |    value_loss         | 0.00934   |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.6      |
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 79200     |
# |    time_elapsed       | 976       |
# |    total_timesteps    | 396000    |
# | train/                |           |
# |    entropy_loss       | -0.0135   |
# |    explained_variance | -0.0881   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 79199     |
# |    policy_loss        | -0.000247 |
# |    value_loss         | 0.0282    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.6     |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 79300    |
# |    time_elapsed       | 977      |
# |    total_timesteps    | 396500   |
# | train/                |          |
# |    entropy_loss       | -0.0189  |
# |    explained_variance | 0.267    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 79299    |
# |    policy_loss        | 0.000424 |
# |    value_loss         | 0.032    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.7     |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 79400    |
# |    time_elapsed       | 979      |
# |    total_timesteps    | 397000   |
# | train/                |          |
# |    entropy_loss       | -0.0123  |
# |    explained_variance | -0.135   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 79399    |
# |    policy_loss        | -0.00043 |
# |    value_loss         | 0.0935   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.7     |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 79500    |
# |    time_elapsed       | 980      |
# |    total_timesteps    | 397500   |
# | train/                |          |
# |    entropy_loss       | -0.0232  |
# |    explained_variance | 0.284    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 79499    |
# |    policy_loss        | 0.0006   |
# |    value_loss         | 0.0403   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.5     |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 79600    |
# |    time_elapsed       | 981      |
# |    total_timesteps    | 398000   |
# | train/                |          |
# |    entropy_loss       | -0.0123  |
# |    explained_variance | -0.402   |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 79599    |
# |    policy_loss        | -0.00031 |
# |    value_loss         | 0.0455   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 12.7     |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 79700    |
# |    time_elapsed       | 982      |
# |    total_timesteps    | 398500   |
# | train/                |          |
# |    entropy_loss       | -0.0287  |
# |    explained_variance | 0.201    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 79699    |
# |    policy_loss        | 0.00119  |
# |    value_loss         | 0.0941   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 12.8      |
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 79800     |
# |    time_elapsed       | 983       |
# |    total_timesteps    | 399000    |
# | train/                |           |
# |    entropy_loss       | -0.0189   |
# |    explained_variance | -0.0584   |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 79799     |
# |    policy_loss        | -0.000339 |
# |    value_loss         | 0.0254    |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 200      |
# |    ep_rew_mean        | 13       |
# | time/                 |          |
# |    fps                | 405      |
# |    iterations         | 79900    |
# |    time_elapsed       | 985      |
# |    total_timesteps    | 399500   |
# | train/                |          |
# |    entropy_loss       | -0.0255  |
# |    explained_variance | 0.269    |
# |    learning_rate      | 0.0001   |
# |    n_updates          | 79899    |
# |    policy_loss        | 0.000481 |
# |    value_loss         | 0.0205   |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 200       |
# |    ep_rew_mean        | 13        |
# | time/                 |           |
# |    fps                | 405       |
# |    iterations         | 80000     |
# |    time_elapsed       | 986       |
# |    total_timesteps    | 400000    |
# | train/                |           |
# |    entropy_loss       | -0.0218   |
# |    explained_variance | -0.12     |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 79999     |
# |    policy_loss        | -0.000582 |
# |    value_loss         | 0.0492    |
# -------------------------------------
# Mean reward: 11.650915399999999 and Standard Deviation: 8.795159948619812

# %%
print(training_values_1)
# Out:
# []
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
from stable_baselines3.common.vec_env import VecVideoRecorder, DummyVecEnv

trajs=[]
objective_values = []
def record_video(env_id, model, video_length=500, prefix="", video_folder="videos/"):
    """
    :param env_id: (str)
    :param model: (RL model)
    :param video_length: (int)
    :param prefix: (str)
    :param video_folder: (str)
    """
    eval_env = DummyVecEnv([lambda: mo.make(env_id, render_mode="rgb_array")])
    #print(eval_env)
    # Start the video at step=0 and record 500 steps
    eval_env = VecVideoRecorder(
        model.get_env(),
        video_folder=video_folder,
        record_video_trigger=lambda step: step == 0,
        video_length=video_length,
        name_prefix=prefix,
    )
    obs_arr = []
    objective_values = []
    obs = eval_env.reset()
    obs_arr.append(obs)
    steps = 0
    for i in range(video_length):
        action, _states = agent.predict(obs, deterministic=True)
        #print(action)
        obs, rewards, done, info = eval_env.step(action) #Why is this not terminated, truncated? -- Stable baseline
        objective_values.append(info[0].get("vector_reward"))
        steps += 1
        #total += rewards
        obs1 = np.append(obs, [action])
        obs_arr.append(obs1)
        #print(obs1)
        if (done):
          obs = eval_env.reset()
          obs_arr = []
          obs_arr.append(obs)
          trajs.append(obs_arr)
          print("Steps =", steps)

    # Close the video recorder
    eval_env.close()

# %%
#For velocity v
x_arr=[]
y_arr=[]
#print(objective_values)
plt.figure(figsize=(15, 6))
for [x,y] in training_values[1:-1]:
  x_arr.append(x)
  y_arr.append(y)

# Plotting the coordinates
plt.scatter(range(len(x_arr)),x_arr,c="blue", marker='o',s=15, label="Movement")
plt.scatter(range(len(y_arr)),y_arr, c="green", marker='o',s=15, label="Speed")
plt.legend()
#plt.ylim(-1.1,1.1)
#plt.xlim(0, 2000)


# Set axis labels and title
plt.xlabel('Episode')
plt.ylabel('Objective Value')
#plt.xlim(-1, 1)
# plt.title('MO
#Mountain Car Scalarized')

# Display the plot
#plt.show()
plt.grid()
plt.savefig("Training {} - {}.jpg".format(scalar_weight,steps), dpi=300)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-15aa01d9303c> in <cell line: 11>()
#       9
#      10 # Plotting the coordinates
# ---> 11 plt.scatter(range(len(x_arr)),x_arr,c="blue", marker='o',s=15, label="Movement")
#      12 plt.scatter(range(len(y_arr)),y_arr, c="green", marker='o',s=15, label="Speed")
#      13 plt.legend()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4582         y = np.ma.ravel(y)
#    4583         if x.size != y.size:
# -> 4584             raise ValueError("x and y must be the same size")
#    4585
#    4586         if s is None:
#
# ValueError: x and y must be the same size

# %%
# Assuming training_values is a list of [x, y, goal_reached] triples

x_arr = np.array([entry[0][0] for entry in training_values])
y_arr = np.array([entry[0][1] for entry in training_values])
z_arr = np.array([entry[0][2] for entry in training_values])
goal_reached = np.array([entry[1] for entry in training_values])

# Define colors based on goal reached or not

plt.figure(figsize=(15, 6))


colors_1 = np.where(goal_reached, 'blue', 'blue')
colors_2 = np.where(goal_reached, 'green', 'green')
colors_3 = np.where(goal_reached, 'orange', 'orange')

# Scatter plot with different colors based on goal reached or not
plt.scatter(range(len(x_arr)), x_arr, marker='o', s=15, c=colors_1, label="Time")
plt.scatter(range(len(y_arr)), y_arr, marker='o', s=15, c=colors_2, label="Movement")
plt.scatter(range(len(z_arr)), z_arr, marker='o', s=15, c=colors_3, label="Speed")


#legend_labels = ['Time Reward (Reached)', 'Time Reward(Not Reached)', 'Movement(Reached)','Movement (Not Reached)' ,'Speed Reward(Reached)', 'Speed Reward(Not Reached)']
legend_labels = ['Time Reward','Backwards Reward','Forwards Reward']
legend_handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markersize=10),
                  plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='lightblue', markersize=10),
                  plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='green', markersize=10),
                  plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='orange', markersize=10),
                  ]

plt.legend(legend_handles, legend_labels)

plt.xlabel('Episode Number')
plt.ylabel('Objective Value')
plt.grid()
plt.savefig("Training {} - {}.jpg".format(scalar_weight, steps), dpi=300)
plt.show()

# %%
# Assuming training_values is a list of [x, y, goal_reached] triples

x_arr = np.array([entry[0][0] for entry in training_values])
y_arr = np.array([entry[0][1] for entry in training_values])
# z_arr = np.array([entry[0][2] for entry in training_values])
goal_reached = np.array([entry[1] for entry in training_values])

# Define colors based on goal reached or not

plt.figure(figsize=(15, 6))


colors_1 = np.where(goal_reached, '#1f77b4', 'blue')
colors_2 = np.where(goal_reached, 'lightgreen', 'green')
# colors_3 = np.where(goal_reached, '#FFD580', 'orange')

# Scatter plot with different colors based on goal reached or not
plt.scatter(range(len(x_arr)), x_arr, marker='o', s=15, c=colors_1, label="Time")
plt.scatter(range(len(y_arr)), y_arr, marker='o', s=15, c=colors_2, label="Movement")
# plt.scatter(range(len(z_arr)), z_arr, marker='o', s=15, c=colors_3, label="Speed")


legend_labels = ['Movement Reward (Reached)', 'Movement Reward (Not Reached)', 'Speed Reward (Reached)','Speed Reward (Not Reached)'] #,'Speed Reward(Reached)', 'Speed Reward(Not Reached)']
legend_handles = [plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='blue', markersize=10),
                  plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='#1f77b4', markersize=10),
                  plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='green', markersize=10),
                  plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='lightgreen', markersize=10),
                  # plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='orange', markersize=10),
                  # plt.Line2D([0], [0], marker='o', color='w', markerfacecolor='#FFD580', markersize=10),
                  ]

plt.legend(legend_handles, legend_labels)

plt.xlabel('Episode Number')
plt.ylabel('Objective Value')
plt.grid()
plt.savefig("Training {} - {}.jpg".format(scalar_weight, steps), dpi=300)
plt.show()

# %%
x_arr=[]
y_arr=[]
#print(objective_values)
plt.figure(figsize=(15, 6))
for [x,y] in training_values[:-1]:
  x_arr.append(x)
  y_arr.append(y)
plt.scatter(y_arr,x_arr, marker='o',s=15)
plt.xlabel('Speed')
plt.ylabel('Time')
plt.savefig("Correlation {} - {}.jpg".format(scalar_weight,steps), dpi=300)
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-a761e5d32650> in <cell line: 8>()
#       6   x_arr.append(x)
#       7   y_arr.append(y)
# ----> 8 plt.scatter(y_arr,x_arr, marker='o',s=15)
#       9 plt.xlabel('Speed')
#      10 plt.ylabel('Time')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4582         y = np.ma.ravel(y)
#    4583         if x.size != y.size:
# -> 4584             raise ValueError("x and y must be the same size")
#    4585
#    4586         if s is None:
#
# ValueError: x and y must be the same size

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming training_values is a list of [x, y, goal_reached] triples

x_arr = np.array([entry[0][0] for entry in training_values])
y_arr = np.array([entry[0][1] for entry in training_values])
goal_reached = np.array([entry[1] for entry in training_values])

# Define colors based on goal reached or not
colors = np.where(goal_reached, 'red', 'green')

plt.figure(figsize=(15, 6))

# Scatter plot with different colors based on goal reached or not
plt.scatter(y_arr, x_arr, marker='o', s=15, c=colors)

plt.xlabel('Speed Reward')
plt.ylabel('Movement Reward')
plt.grid()
plt.savefig("Correlation {} - {}.jpg".format(scalar_weight, steps), dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming training_values is a list of [x, y, goal_reached] triples

x_arr = np.array([entry[0][0] for entry in training_values])
y_arr = np.array([entry[0][1] for entry in training_values])
z_arr = np.array([entry[0][2] for entry in training_values])
goal_reached = np.array([entry[1] for entry in training_values])

# Define colors based on goal reached or not
colors = np.where(goal_reached, 'red', 'green')

plt.figure(figsize=(15, 6))

# Scatter plot with different colors based on goal reached or not
plt.scatter(y_arr, x_arr, marker='o', s=15, c=colors)

plt.xlabel('Speed Reward')
plt.ylabel('Time Reward')
plt.zlabel('Movement Reward')
plt.grid()
plt.savefig("Correlation {} - {}.jpg".format(scalar_weight, steps), dpi=300)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-a707f051262b> in <cell line: 21>()
#      19 plt.xlabel('Speed Reward')
#      20 plt.ylabel('Time Reward')
# ---> 21 plt.zlabel('Movement Reward')
#      22 plt.grid()
#      23 plt.savefig("Correlation {} - {}.jpg".format(scalar_weight, steps), dpi=300)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'zlabel'

# %%
#For the 3 objectives case
x_arr=[]
y_arr=[]
z_arr=[]
#print(objective_values)
plt.figure(figsize=(15, 6))
for [x,y,z] in training_values[:-1]:
  x_arr.append(x)
  y_arr.append(y)
  z_arr.append(z)

# Plotting the coordinates
plt.scatter(range(len(x_arr)),x_arr,c="blue", marker='o',s=15, label="Time")
plt.scatter(range(len(y_arr)),y_arr, c="green", marker='o',s=15, label="Movement")
plt.scatter(range(len(z_arr)),z_arr, c="orange", marker='o',s=15, label="Velocity")
plt.legend()
#plt.ylim(-1.1,1.1)
#plt.xlim(0, 2000)


# Set axis labels and title
plt.xlabel('Episode')
plt.ylabel('Objective Value')
#plt.xlim(-1, 1)
# plt.title('MO Mountain Car Scalarized')

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-0d753649a3d7> in <cell line: 7>()
#       5 #print(objective_values)
#       6 plt.figure(figsize=(15, 6))
# ----> 7 for [x,y,z] in training_values[:-1]:
#       8   x_arr.append(x)
#       9   y_arr.append(y)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
#For velocity v
#print(training_values)
x_arr=[]
y_arr=[]
#print(objective_values)
plt.figure(figsize=(15, 6))
for [x,y] in training_values[:-1]:
  x_arr.append(x)
  y_arr.append(y)

# Plotting the coordinates
plt.plot(range(len(x_arr)),x_arr,c="blue", label="Time")
plt.plot(range(len(y_arr)),y_arr, c="green", label="Velocity")
plt.legend()
#plt.ylim(-1.1,1.1)
#plt.xlim(0, 2000)


# Set axis labels and title
plt.xlabel('Episode')
plt.ylabel('Objective Value')
#plt.xlim(-1, 1)
# plt.title('MO Mountain Car Scalarized')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D

# Assuming you have a v_arr containing values 0, 1, 2 corresponding to each (x, y) point
v_arr = []
x_arr = []
y_arr = []

for [x, y, z] in trajs[5][1:-1]:
    x_arr.append(x)
    y_arr.append(y)
    v_arr.append(z)

# Linking actions to labels and colors
action_mapping = {0: {'label': 'Backward', 'color': 'orange'},
                  1: {'label': 'Static', 'color': 'green'},
                  2: {'label': 'Forward', 'color': 'blue'}}

# Create a set of unique action-color pairs
unique_action_color_pairs = {(entry['label'], entry['color']) for action, entry in action_mapping.items()}

# Create a legend with custom handles and colors
legend_handles = [Line2D([0], [0], marker='o', color=color, markerfacecolor=color, markersize=10, label=label) for label, color in unique_action_color_pairs]

# Plotting the coordinates with RGB colors based on action_mapping
scatter = plt.scatter(x_arr, y_arr, c=[action_mapping[action]['color'] for action in v_arr], marker='o', s=15)

# Create a legend
plt.legend(handles=legend_handles, title='Actions', loc="lower right")

# Set axis labels and title
plt.xlabel('Position')
plt.ylabel('Velocity')

plt.xlim([-1.2, 0.6])
plt.ylim([-0.07, 0.07])

plt.grid()
plt.savefig(f"Trajectory {scalar_weight}-{steps}-forward.jpg")
# Display the plot
plt.show()

# %%
#For velocity v^2
x_arr=[]
y_arr=[]
print(obs_arr)

for [[x,y]] in obs_arr[:-1]:
  x_arr.append(x)
  y_arr.append(y**2)

# Plotting the coordinates
plt.scatter(x_arr, y_arr, marker='o')

# Set axis labels and title
plt.xlabel('Position')
plt.ylabel('Velocity')
plt.title('MO Mountain Car Scalarized [1,0,0]')

# Display the plot
plt.show()
# Out:
# [array([[-0.5463648,  0.       ]], dtype=float32), array([[-0.5471942 , -0.00082939]], dtype=float32), array([[-0.5488468 , -0.00165257]], dtype=float32), array([[-0.5513101 , -0.00246339]], dtype=float32), array([[-0.55456597, -0.00325579]], dtype=float32), array([[-0.5585898 , -0.00402388]], dtype=float32), array([[-0.56335175, -0.00476192]], dtype=float32), array([[-0.56881624, -0.00546448]], dtype=float32), array([[-0.5749426 , -0.00612639]], dtype=float32), array([[-0.5816854 , -0.00674283]], dtype=float32), array([[-0.58899486, -0.00730939]], dtype=float32), array([[-0.5968169 , -0.00782206]], dtype=float32), array([[-0.6050942 , -0.00827732]], dtype=float32), array([[-0.6137664 , -0.00867218]], dtype=float32), array([[-0.62277055, -0.00900414]], dtype=float32), array([[-0.6320418 , -0.00927128]], dtype=float32), array([[-0.641514  , -0.00947222]], dtype=float32), array([[-0.65112025, -0.00960619]], dtype=float32), array([[-0.6607931 , -0.00967294]], dtype=float32), array([[-0.67046595, -0.00967279]], dtype=float32), array([[-0.68007255, -0.00960658]], dtype=float32), array([[-0.6895482 , -0.00947565]], dtype=float32), array([[-0.69882995, -0.00928181]], dtype=float32), array([[-0.70785725, -0.00902728]], dtype=float32), array([[-0.7165719 , -0.00871465]], dtype=float32), array([[-0.7249188 , -0.00834685]], dtype=float32), array([[-0.73284584, -0.00792708]], dtype=float32), array([[-0.74030465, -0.00745879]], dtype=float32), array([[-0.7472502 , -0.00694559]], dtype=float32), array([[-0.7536415 , -0.00639126]], dtype=float32), array([[-0.75944114, -0.00579967]], dtype=float32), array([[-0.7646159 , -0.00517477]], dtype=float32), array([[-0.7691365 , -0.00452058]], dtype=float32), array([[-0.77297765, -0.00384113]], dtype=float32), array([[-0.77611804, -0.00314044]], dtype=float32), array([[-0.7785406 , -0.00242257]], dtype=float32), array([[-0.7802322 , -0.00169154]], dtype=float32), array([[-0.78118354, -0.00095138]], dtype=float32), array([[-7.8138965e-01, -2.0610722e-04]], dtype=float32), array([[-7.808494e-01,  5.402742e-04]], dtype=float32), array([[-0.77956563,  0.00128375]], dtype=float32), array([[-0.77754533,  0.00202032]], dtype=float32), array([[-0.77479935,  0.00274595]], dtype=float32), array([[-0.7693427 ,  0.00545663]], dtype=float32), array([[-0.7612055 ,  0.00813723]], dtype=float32), array([[-0.7504333 ,  0.01077216]], dtype=float32), array([[-0.7370882 ,  0.01334512]], dtype=float32), array([[-0.72124916,  0.01583905]], dtype=float32), array([[-0.7030131 ,  0.01823607]], dtype=float32), array([[-0.6824955 ,  0.02051764]], dtype=float32), array([[-0.65983075,  0.02266474]], dtype=float32), array([[-0.6351724 ,  0.02465828]], dtype=float32), array([[-0.6086929 ,  0.02647954]], dtype=float32), array([[-0.5805821 ,  0.02811084]], dtype=float32), array([[-0.55104595,  0.02953613]], dtype=float32), array([[-0.5203042 ,  0.03074175]], dtype=float32), array([[-0.48858714,  0.03171705]], dtype=float32), array([[-0.4561322 ,  0.03245494]], dtype=float32), array([[-0.4231798 ,  0.03295239]], dtype=float32), array([[-0.3899692 ,  0.03321059]], dtype=float32), array([[-0.35673422,  0.03323499]], dtype=float32), array([[-0.3236991 ,  0.03303513]], dtype=float32), array([[-0.29107493,  0.03262414]], dtype=float32), array([[-0.2590567 ,  0.03201825]], dtype=float32), array([[-0.2278207,  0.031236 ]], dtype=float32), array([[-0.19752318,  0.03029752]], dtype=float32), array([[-0.16929942,  0.02822375]], dtype=float32), array([[-0.1432601 ,  0.02603933]], dtype=float32), array([[-0.11949342,  0.02376668]], dtype=float32), array([[-0.09806781,  0.0214256 ]], dtype=float32), array([[-0.07903479,  0.01903302]], dtype=float32), array([[-0.06243182,  0.01660297]], dtype=float32), array([[-0.04828513,  0.01414669]], dtype=float32), array([[-0.03661226,  0.01167287]], dtype=float32), array([[-0.02742433,  0.00918794]], dtype=float32), array([[-0.02172794,  0.00569639]], dtype=float32), array([[-0.01952624,  0.0022017 ]], dtype ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x_arr = []
y_arr = []
z_arr = []

# Assuming obs_arr is a list of lists with [[x, y, z]] format
print(obs_arr)
for [x, y, z] in obs_arr[1:-1]:
    x_arr.append(x)
    y_arr.append(y)
    z_arr.append(z)

# Creating a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_arr, y_arr, z_arr, marker='o')

# Set axis labels and title
ax.set_xlabel('Position')
ax.set_ylabel('Velocity')
ax.set_zlabel('Reward')
ax.set_title('3D Scatter Plot of Coordinates')

# Display the plot
plt.show()
# Out:
# []
# Moviepy - Building video /content/dissertation/videos/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /content/dissertation/videos/-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /content/dissertation/videos/-step-0-to-step-1000.mp4

# %%
record_video(environment, agent, video_length=1000)
#record_video("mo-mountaincar-v0", agent, video_length=1000)
#record_video("mo-mountaincar-velocity", agent, video_length=1000)
#record_video("MountainCar-v0", agent, video_length=1000)
#record_video("MountainCarContinuous-v0", agent, video_length=1000)
# Out:
# Moviepy - Building video /content/dissertation/videos/-step-0-to-step-1000.mp4.
# Moviepy - Writing video /content/dissertation/videos/-step-0-to-step-1000.mp4
# Moviepy - Done !
# Moviepy - video ready /content/dissertation/videos/-step-0-to-step-1000.mp4
# Steps = 150
# Moviepy - Building video /content/dissertation/videos/-step-150-to-step-1150.mp4.
# Moviepy - Writing video /content/dissertation/videos/-step-150-to-step-1150.mp4
# Moviepy - Done !
# Moviepy - video ready /content/dissertation/videos/-step-150-to-step-1150.mp4
# Steps = 257
# Moviepy - Building video /content/dissertation/videos/-step-257-to-step-1257.mp4.
# Moviepy - Writing video /content/dissertation/videos/-step-257-to-step-1257.mp4
# Moviepy - Done !
# Moviepy - video ready /content/dissertation/videos/-step-257-to-step-1257.mp4
# Steps = 408
# Moviepy - Building video /content/dissertation/videos/-step-408-to-step-1408.mp4.
# Moviepy - Writing video /content/dissertation/videos/-step-408-to-step-1408.mp4
# Moviepy - Done !
# Moviepy - video ready /content/dissertation/videos/-step-408-to-step-1408.mp4
# Steps = 557
# Moviepy - Building video /content/dissertation/videos/-step-557-to-step-1557.mp4.
# Moviepy - Writing video /content/dissertation/videos/-step-557-to-step-1557.mp4
# Moviepy - Done !
# Moviepy - video ready /content/dissertation/videos/-step-557-to-step-1557.mp4
# Steps = 668
# Moviepy - Building video /content/dissertation/videos/-step-668-to-step-1668.mp4.
# Moviepy - Writing video /content/dissertation/videos/-step-668-to-step-1668.mp4
# Moviepy - Done !
# Moviepy - video ready /content/dissertation/videos/-step-668-to-step-1668.mp4
# Steps = 819
# Moviepy - Building video /content/dissertation/videos/-step-819-to-step-1819.mp4.
# Moviepy - Writing video /content/dissertation/videos/-step-819-to-step-1819.mp4
# Moviepy - Done !
# Moviepy - video ready /content/dissertation/videos/-step-819-to-step-1819.mp4
# Steps = 926
# Moviepy - Building video /content/dissertation/videos/-step-926-to-step-1926.mp4.
# Moviepy - Writing video /content/dissertation/videos/-step-926-to-step-1926.mp4
# Moviepy - Done !
# Moviepy - video ready /content/dissertation/videos/-step-926-to-step-1926.mp4

# %%
len(trajs)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 7

# %%
#To display the video
from IPython.display import HTML
from base64 import b64encode
mp4 = open('videos/-step-557-to-step-1557.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
import os
dir = "/dissertation/models/"
os.makedirs(dir, exist_ok=True)

# %%
def evaluate(agent):
    #eval_env = mo.LinearReward(mo.make(environment, render_mode="rgb_array"), weight=np.array([x, (1-x)]))
    #eval_env = mo.make(environment, render_mode="rgb_array")
    total_evaluation = [0,0]
    for k in range(100):
      eval_env = agent.get_env()
      obs = eval_env.reset()
      for j in range(200):
          action, _states = agent.predict(obs)
          obs, rewards, done, info = eval_env.step(action) #Why is this not terminated, truncated? -- Stable baseline
          total_evaluation+=(info[0].get("vector_reward"))
          #total += rewards
            #print(obs1)
          if (done):
            break
    total_evaluation = total_evaluation/100
    print(total_evaluation)
    return total_evaluation

# %%
#Trying to generate Pareto Front
import numpy as np
results1 = []
sd = []

###TODO: Introduce model saving

def ParetoGeneration():
  first =np.linspace(0.01, 0.1, num=10)
  #np.linspace has precison issues
    # Linear scalarizes the environment
  for x in first:
    #env = mo.LinearReward(mo.make("mo-mountaincar-velocity-move", render_mode="rgb_array"), weight=np.array([x, (1-x)]))
    print("Objective 1 weight: {} and Objective 2 weight: {}".format(x, (1-x)))
    env = mo.LinearReward(mo.make(environment, render_mode="rgb_array"), weight=np.array([x, (1-x)]))

    print("Action space:", env.action_space)

    agent = sb3.DQN(policy="MlpPolicy",
        env=env,
        seed=0,
        learning_rate=0.0001, #Originally, 0.0001
        buffer_size=int(2e5),  # Replay buffer size
        learning_starts=1000,  # Number of steps before starting training
        train_freq=4,          # Number of actions between updates
        gradient_steps=1,      # Number of optimization steps per batch
        target_update_interval=1000,  # Frequency (in steps) to update the target network
        exploration_fraction=1,     # Fraction of the total training steps for exploration
        exploration_final_eps=0,   # Final epsilon value for exploration
        gamma=0.9,
        max_grad_norm=5,
        policy_kwargs=None,
      verbose=0)

    agent.learn(total_timesteps=400000)

    agent.save(f"models/({x},{(1-x)})")

    #Introduce Model Saving
    answer = evaluate(agent)
    results1.append([x,1-x,answer])
    print((x*answer[0])+((1-x)*answer[1]))
    _, standard_dev = evaluate_policy(agent, agent.get_env(), n_eval_episodes=100)
    sd.append([x,1-x,standard_dev])
    #print(f"Mean reward: {mean_reward} and Standard Deviation: {std_reward}")

ParetoGeneration()
# Out:
# Objective 1 weight: 0.01 and Objective 2 weight: 0.99
# Box([-1.  0.], [0.  1.1], (2,), float32)
# Action space: Discrete(3)
# [-127.32         56.10434822]
# 54.27010473952461
# Objective 1 weight: 0.020000000000000004 and Objective 2 weight: 0.98
# Box([-1.  0.], [0.  1.1], (2,), float32)
# Action space: Discrete(3)
# [-117.81         49.27105149]
# 45.929430464059266
# Objective 1 weight: 0.030000000000000006 and Objective 2 weight: 0.97
# Box([-1.  0.], [0.  1.1], (2,), float32)
# Action space: Discrete(3)
# [-136.23         62.82984564]
# 56.85805026648887
# Objective 1 weight: 0.04000000000000001 and Objective 2 weight: 0.96
# Box([-1.  0.], [0.  1.1], (2,), float32)
# Action space: Discrete(3)
# [-122.9         56.7028556]
# 49.51874137822627
# Objective 1 weight: 0.05000000000000001 and Objective 2 weight: 0.95
# Box([-1.  0.], [0.  1.1], (2,), float32)
# Action space: Discrete(3)
# [-109.67         56.44643414]
# 48.14061243308411
# Objective 1 weight: 0.06000000000000001 and Objective 2 weight: 0.94
# Box([-1.  0.], [0.  1.1], (2,), float32)
# Action space: Discrete(3)
# [-106.87         53.74257197]
# 44.10581765322929
# Objective 1 weight: 0.07 and Objective 2 weight: 0.9299999999999999
# Box([-1.  0.], [0.  1.1], (2,), float32)
# Action space: Discrete(3)
# [-96.3         58.45881808]
# 47.62570081387773
# Objective 1 weight: 0.08 and Objective 2 weight: 0.92
# Box([-1.  0.], [0.  1.1], (2,), float32)
# Action space: Discrete(3)
# [-73.37        40.93814668]
# 31.79349494712185
# Objective 1 weight: 0.09000000000000001 and Objective 2 weight: 0.91
# Box([-1.  0.], [0.  1.1], (2,), float32)
# Action space: Discrete(3)
# [-69.58        50.46692095]
# 39.66269805998875
# Objective 1 weight: 0.1 and Objective 2 weight: 0.9
# Box([-1.  0.], [0.  1.1], (2,), float32)
# Action space: Discrete(3)

# %%
print(results1)
# Out:
# [[0.0, 1.0, array([-129.33      ,    5.67874955])], [0.1, 0.9, array([-113.98      ,    4.49195537])], [0.2, 0.8, array([-148.94      ,    4.21233408])], [0.30000000000000004, 0.7, array([-178.63      ,    6.20810296])], [0.4, 0.6, array([-132.44      ,    4.81516047])], [0.5, 0.5, array([-146.9       ,    5.07740701])], [0.6000000000000001, 0.3999999999999999, array([-153.7       ,    2.91725097])], [0.7000000000000001, 0.29999999999999993, array([-168.13      ,    5.57978616])], [0.8, 0.19999999999999996, array([-200.        ,    2.08006077])], [0.9, 0.09999999999999998, array([-171.38      ,    2.68572028])], [1.0, 0.0, array([-178.1       ,    5.87531239])]]

# %%
results1= [[   0.  ,    1.  , [-123.49,   52.62]],
       [   0.1 ,    0.9 , [-130.25,   57.23]],
       [   0.2 ,    0.8 , [-118.45,   49.33]],
       [   0.3 ,    0.7 , [-119.3 ,   49.42]],
       [   0.4 ,    0.6 , [-115.13,   41.49]],
       [   0.5 ,    0.5 , [-134.17,   54.78]],
       [   0.6 ,    0.4 , [-139.56,   39.46]],
       [   0.7 ,    0.3 , [-111.37,   40.32]],
       [   0.8 ,    0.2 , [-118.42,   43.4 ]],
       [   0.9 ,    0.1 , [-149.19,   44.96]],
       [   1.  ,    0.  , [-178.1 ,   58.75]]]

results1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [[0.0, 1.0, [-123.49, 52.62]],
#  [0.1, 0.9, [-130.25, 57.23]],
#  [0.2, 0.8, [-118.45, 49.33]],
#  [0.3, 0.7, [-119.3, 49.42]],
#  [0.4, 0.6, [-115.13, 41.49]],
#  [0.5, 0.5, [-134.17, 54.78]],
#  [0.6, 0.4, [-139.56, 39.46]],
#  [0.7, 0.3, [-111.37, 40.32]],
#  [0.8, 0.2, [-118.42, 43.4]],
#  [0.9, 0.1, [-149.19, 44.96]],
#  [1.0, 0.0, [-178.1, 58.75]]]

# %%
from sklearn.preprocessing import MinMaxScaler

result2 = results1
scaler = MinMaxScaler()
#x_arr = [[entry[2][0],entry[2][1]] for entry in result2]  # x-axis corresponds to reward1
x_arr = [[entry[2][0],entry[2][1]] for entry in result2]

# Fit and transform the data
normalized_data = scaler.fit_transform(x_arr)

# %%
import matplotlib.pyplot as plt

# result2 = results1 + results
x_values = [normalized_entry[0] for normalized_entry in normalized_data]  # x-axis corresponds to reward1
y_values = [normalized_entry[1] for normalized_entry in normalized_data]  # y-axis corresponds to reward2

# Plotting the scatter plot
plt.scatter(x_values, y_values)

# Set the margin for labels outside the plot
label_margin = 0.02

# Mark each point by (x, y) outside the plot
# for i, entry in enumerate(results):
#     plt.text(entry[2][0] + label_margin, entry[2][1] + label_margin, f'({entry[0]}, {entry[1]})', fontsize=6, ha='center')

# for i, entry in enumerate(results1):
#     plt.text(entry[2][0] + label_margin, entry[2][1] + label_margin, f'({round(entry[0], 1)}, {round(entry[1], 1)})', fontsize=6, ha='center')

# Adding labels and title
plt.xlabel('Movement')
plt.ylabel('Speed')
#plt.title('Pareto Front for MO Mountain Car')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# result2 = results1 + results
x_values = [entry[2][0] for entry in results1]  # x-axis corresponds to reward1
y_values = [entry[2][1] for entry in results1]  # y-axis corresponds to reward2
#sd_values = [val[2] for val in sd]

# Plotting the scatter plot
#plt.scatter(x_values, y_values, s = sd_values)
plt.scatter(x_values, y_values, s=10)

# Set the margin for labels outside the plot
label_margin = 0.02

# Mark each point by (x, y) outside the plot
# for i, entry in enumerate(results):
#     plt.text(entry[2][0] + label_margin, entry[2][1] + label_margin, f'({entry[0]}, {entry[1]})', fontsize=6, ha='center')

for i, entry in enumerate(results1):
    print(entry[0])
    if round(entry[0], 1)!= 0.3:
      plt.text(entry[2][0] + label_margin, entry[2][1] + label_margin + 0.15, f'({round(entry[0], 1)}, {round(entry[1], 1)})', fontsize=8, va='bottom', ha='center')

pareto_x = [10,1,0,2,7]
pareto_y = [0,9,10,8,3]
pareto_front_x = [x_values[i] for i in pareto_x]
pareto_front_y = [y_values[i] for i in pareto_x]
print(pareto_front_x,pareto_front_y)
plt.plot(pareto_front_x, pareto_front_y, 'k-')  # 'k-' means a black solid line
plt.fill_between(pareto_front_x, np.min(y_values),pareto_front_y, color='gray', alpha=0.2, hatch="//")


# Adding labels and title
plt.xlabel('Average Time Reward')
plt.ylabel('Average Speed Reward')
# plt.title('Pareto Front for MO Mountain Car')

#plt.gca().invert_xaxis()
# Display the plot

plt.savefig("Pareto.jpg", dpi=300)
plt.show()
# Out:
# 0.0
# 0.1
# 0.2
# 0.30000000000000004
# 0.4
# 0.5
# 0.6000000000000001
# 0.7000000000000001
# 0.8
# 0.9
# 1.0
# [-178.1, -130.25, -123.49, -118.45, -111.37] [58.75312386402131, 57.23385614715022, 52.623726502106585, 49.33271392708353, 40.32083426211651]

# %%
import matplotlib.pyplot as plt

# result2 = results1 + results
x_values = [entry[2][0] for entry in results1]  # x-axis corresponds to reward1
y_values = [entry[2][1] for entry in results1]  # y-axis corresponds to reward2
sd_values = [val[2] for val in sd]

# Plotting the scatter plot

# Set the margin for labels outside the plot
label_margin = 0.02

# Mark each point by (x, y) outside the plot
# for i, entry in enumerate(results):
#     plt.text(entry[2][0] + label_margin, entry[2][1] + label_margin, f'({entry[0]}, {entry[1]})', fontsize=6, ha='center')
std_devs_normalized = (np.array(sd_values) - np.min(sd_values)) / (np.max(sd_values) - np.min(sd_values))

plt.scatter(x_values, y_values, s = std_devs_normalized*100)

for i, entry in enumerate(results1):
    plt.text(entry[2][0] + label_margin, entry[2][1] + label_margin, f'({round(entry[0], 1)}, {round(entry[1], 1)})', fontsize=10, ha='center')

# Adding labels and title
plt.xlabel('Time')
plt.ylabel('Velocity')
plt.title('Pareto Front for MO Mountain Car')

# Display the plot
plt.show()
plt.savefig("Movement-Velocity-sd-normalized.jpg", dpi=300)

# %%
import matplotlib.pyplot as plt

# Assuming you have the standard deviation values for x and y axes
x_sd_values = [sd_x for sd_x in sd_values_x]  # Replace sd_values_x with your actual standard deviation values for x-axis
y_sd_values = [sd_y for sd_y in sd_values_y]  # Replace sd_values_y with your actual standard deviation values for y-axis

# Calculate the average standard deviation
avg_sd = (sum(x_sd_values) + sum(y_sd_values)) / (len(x_sd_values) + len(y_sd_values))

# result2 = results1 + results
x_values = [entry[2][0] for entry in results1]  # x-axis corresponds to reward1
y_values = [entry[2][1] for entry in results1]  # y-axis corresponds to reward2

# Plotting the scatter plot with dot size based on standard deviation
plt.scatter(x_values, y_values, s=[(sd_x + sd_y) / (2 * avg_sd) * 100 for sd_x, sd_y in zip(x_sd_values, y_sd_values)])

# Set the margin for labels outside the plot
label_margin = 0.02

# Mark each point by (x, y) outside the plot
for i, entry in enumerate(results1):
    plt.text(entry[2][0] + label_margin, entry[2][1] + label_margin, f'({round(entry[0], 1)}, {round(entry[1], 1)})', fontsize=6, ha='center')

# Adding labels and title
plt.xlabel('Time')
plt.ylabel('Velocity')
plt.title('Pareto Front for MO Mountain Car')

# Display the plot
plt.show()

# %%
reward_episodes = []
###For the reward for each objective
class EvalCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contain the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """
    def __init__(self, check_freq: int, verbose=1):
        super(EvalCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = None
        self.episode_sum = [0,0]
        self.training_values = []

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.training_env.buf_dones[0]:
          self.training_values.append(self.episode_sum)
          self.episode_sum = [0,0]
        else:
          self.episode_sum += self.training_env.buf_infos[0].get("vector_reward")
        return True
    def _on_training_end(self) -> None:
        reward_episodes.append(self.training_values)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# !git config --global user.email "praanavgupta@gmail.com"
# !git config --global user.name "Pranav Gupta"

# %%
#Push the graphs or models to Github
# !git add --all
# !git commit -am 'Adding Pareto Models'
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [main e2ef252] Adding Pareto Models
#  18 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 TimeSpeedPareto.jpg
#  create mode 100644 mo_gymnasium/__pycache__/__init__.cpython-310.pyc
#  create mode 100644 mo_gymnasium/__pycache__/utils.cpython-310.pyc
#  create mode 100644 mo_gymnasium/envs/__pycache__/__init__.cpython-310.pyc
#  create mode 100644 mo_gymnasium/envs/mountain_car/__pycache__/__init__.cpython-310.pyc
#  create mode 100644 mo_gymnasium/envs/mountain_car_velocity_v2/__pycache__/__init__.cpython-310.pyc
#  create mode 100644 mo_gymnasium/envs/mountain_car_velocity_v2/__pycache__/mountain_car_velocity_v2.cpython-310.pyc
#  create mode 100644 time-speedParetoModels/(0.0,1.0)
#  create mode 100644 time-speedParetoModels/(0.1,0.9)
#  create mode 100644 time-speedParetoModels/(0.2,0.8)
#  create mode 100644 time-speedParetoModels/(0.30000000000000004,0.7)
#  create mode 100644 time-speedParetoModels/(0.4,0.6)
#  create mode 100644 time-speedParetoModels/(0.5,0.5)
#  create mode 100644 time-speedParetoModels/(0.6000000000000001,0.3999999999999999)
#  create mode 100644 time-speedParetoModels/(0.7000000000000001,0.29999999999999993)
#  create mode 100644 time-speedParetoModels/(0.8,0.19999999999999996)
#  create mode 100644 time-speedParetoModels/(0.9,0.09999999999999998)
#  create mode 100644 time-speedParetoModels/(1.0,0.0)

# %%
# !git push
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Enumerating objects: 38, done.
# Counting objects: 100% (38/38), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (29/29), done.
# Writing objects: 100% (29/29), 604.24 KiB | 11.85 MiB/s, done.
# Total 29 (delta 7), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (7/7), completed with 6 local objects.
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/pranavg23/morl-moutain-car.git
# To https://github.com/pranavg23/dissertation.git
#    d430086..e2ef252  main -> main

# %%
# !git pull
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 15 (delta 10), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), 4.58 KiB | 1.15 MiB/s, done.
# From https://github.com/pranavg23/dissertation
#    e2ef252..33bf216  main       -> origin/main
# Updating e2ef252..33bf216
# Fast-forward
#  time-speedParetoModels/{(0.30000000000000004,0.7) => (0.3,0.7)}                | Bin
#  time-speedParetoModels/{(0.6000000000000001,0.3999999999999999) => (0.6,0.4)}  | Bin
#  time-speedParetoModels/{(0.7000000000000001,0.29999999999999993) => (0.7,0.3)} | Bin
#  time-speedParetoModels/{(0.8,0.19999999999999996) => (0.8,0.2)}                | Bin
#  time-speedParetoModels/{(0.9,0.09999999999999998) => (0.9,0.1)}                | Bin
#  5 files changed, 0 insertions(+), 0 deletions(-)
#  rename time-speedParetoModels/{(0.30000000000000004,0.7) => (0.3,0.7)} (100%)
#  rename time-speedParetoModels/{(0.6000000000000001,0.3999999999999999) => (0.6,0.4)} (100%)
#  rename time-speedParetoModels/{(0.7000000000000001,0.29999999999999993) => (0.7,0.3)} (100%)
#  rename time-speedParetoModels/{(0.8,0.19999999999999996) => (0.8,0.2)} (100%)
#  rename time-speedParetoModels/{(0.9,0.09999999999999998) => (0.9,0.1)} (100%)

# %%
#Load stablebaseline3 model, we need training though!
